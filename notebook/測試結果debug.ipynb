# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
df = pd.read_excel('../predict_result/0927到1210測試結果.xlsx').astype(str)
print(df.columns)
df = df.loc[df['錯誤原因']!='無錯誤',['45A','受益人','預測產品','預測產品使用方式','預測產品(取長度最長)','推薦公司事業部','根據產品預測代號','利用公司名稱預測公司代號','集成預測代號','from']]
print(df.shape)
display(df.sample(42))
df.to_excel('../output/錯誤型態彙整.xlsx')
# Out:
# Index(['45A', '項次', '電文代號', '銀行', '20', '回傳代碼', '回傳訊息', '建檔日期', '受益人', '金額',
#        '推薦公司事業部', '是否已轉MIS', 'MEMO', 'from', '50', '59', '46A', '47A', '78',
#        'memo', 'Unnamed: 5', '預測產品', '預測產品(取長度最長)', '預測產品使用方式', '根據產品預測部門',
#        '根據產品預測代號', '預測開狀人', '利用公司名稱預測公司代號', 'DIVSION', 'DIVSION預測代號', '集成預測代號',
#        '銀行輸入', '開狀銀行', '正確與否', '錯誤原因', 'EXPNO'],
#       dtype='object')
# (181, 10)
#                                                     45A  \
# 13      COMMODITY DPHP TOTAL QUANTITY 16MTS UNIT PRI...
# 1081   POLYESTER FILM PO NBKNBPRICE TERMS CIF HAIPHO...
# 1393   POLYESTER RESIN PET RESIN BOTTLE GRADE 3802 P...
# 498    300000 BBLS 10PCT OF GASOIL 005PCT SCOUNTRY O...
# 490    POLYESTER STAPLE FIBER QUANTITY 23000 KGS 4D ...
# 1693   EXPORT RESIN AND QUALITY QUANTITY DESCRIPTION...
# 1370   PRODUCT GLACIAL ACRYLIC ACID 1 FCLQUANTITY 16...
# 1514   PLATE FILM100PCT RECYCLED POSTCONSUMER POLYES...
# 875    ETHYLENEPROPYLENE COPOLYMERSPP COPOLYMER YUNG...
# 1725   FOB MAILIAO TAIWANBASE OIL 150NPRICING 700MT ...
# 1690   ETHYLENEPROPYLENE COPOLYMERS PP COPOLYMER YUN...
# 1415   ABS AG15A1H QUANTITY2500MT UNIT PRICE USD2350...
# 325    EPOXY RESIN NPEL127HBENEFICIARY MUST CERTIFY ...
# 1083   POLYESTER FILM PO NAKNMPRICE TERMS CIF SHEKOU...
# 762    32MTS OF PVC SUSPENSION S65 AT USD1660MTTOTAL...
# 1376   POLYAMIDEQUANTITY 16000 KGSNAN YA PA6 2100HNC...
# 1163   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 647    COMMODITY PVC RESIN S60QUANTITY 700MTSUNIT PR...
# 506    PRICE TERM C I F HONG KONGPA6 100PER CENT PRE...
# 1087   TERMS OF PRICE FOB MAILIAO TAIWAN COUNTRY OF ...
# 1757    COMMODITY DESCRIPTION   QUANTITY UNIT PRICE ...
# 1664    PLASTIC RESIN CIF SEMARANG INDONESIA1 4 X 20...
# 1585   COUNTRY OF ORIGIN TAIWANPRICE TERMS CIF SOUTH...
# 559    FOB ANY PORT IN TAIWANTAIRILIN BRANDFLAME RET...
# 1381   PURIFIED TEREPHTHALIC ACID QUANTITY 75020 MT ...
# 1124   COMMODITYNAN YA RELEASE FILMPET L130CQUANTITY...
# 996     COMMODITY TAISOX WAXF QUANTITY 25 MTS UNIT P...
# 283    PRODUCT METHACRYLATE ACIDQUANTITY 1560000 KGS...
# 245    54 MT OF EPOXIDIZED SOYBEAN OIL ESO132 AT USD...
# 192    EPOXIDIZED SOYABEAN OIL ESO132X QUANTITY 18MT...
# 1475   DOORS AND FRAMES FIBERGLASS AND ACCESSORIESCF...
# 1375   525 MT OF PVC MASS RESIN B57 AT A UNIT PRICE ...
# 1374   PVC SUSPENSION RESIN S65D 25KG BAGS QTY 36 MT...
# 1270   TERMS OF PRICE FOB TAIWAN PORTCOUNTRY OF ORIG...
# 324    EPOXY RESIN NPEL127HBENEFICIARY MUST CERTIFY ...
# 1056   FOB ANY PORT IN TAIWANEVA 7350M PRIME GRADE 5...
# 1679   LLDPE 3490 384MT USD1280MTH0FP36HDPE 8010 204...
# 371     COMMODITY PURIFIED TEREPHTHALIC ACID QUANTIT...
# 1584   COMMODITY BPA BISPHENOLAQUANTITY 1500MTSCONTR...
# 320    CIF CAT LAI HO CHI MINH PORT VIETNAMPOLYOXYME...
# 601    1600 MT EPOXIDIZED SOYBEAN OIL ESO132X AT THE...
# 1319   1 BASE OIL 150NPRICING 1215MT 5 ICIS PRICING ...
#
#                                          受益人  \
# 13                NANYA PLASTICS CORPORATION
# 1081                         NAN YA PLASTICS
# 1393                         NAN YA PLASTICS
# 498                    FORMOSA PETROCHEMICAL
# 490               NANYA PLASTICS CORPORATION
# 1693                         NAN YA PLASTICS
# 1370                        FORMOSA PLASTICS
# 1514                         NAN YA PLASTICS
# 875                         FORMOSA PLASTICS
# 1725                   FORMOSA PETROCHEMICAL
# 1690                        FORMOSA PLASTICS
# 1415             FORMOSA CHEMICALS AND FIBRE
# 325               NANYA PLASTICS CORPORATION
# 1083                         NAN YA PLASTICS
# 762                         FORMOSA PLASTICS
# 1376                         NAN YA PLASTICS
# 1163                        FORMOSA PLASTICS
# 647                         FORMOSA PLASTICS
# 506              FORMOSA CHEMICALS AND FIBRE
# 1087                         NAN YA PLASTICS
# 1757              NANYA PLASTICS CORPORATION
# 1664                        FORMOSA PLASTICS
# 1585              NANYA PLASTICS CORPORATION
# 559                          NAN YA PLASTICS
# 1381             FORMOSA CHEMICALS AND FIBRE
# 1124                         NAN YA PLASTICS
# 996                         FORMOSA PLASTICS
# 283                         FORMOSA PLASTICS
# 245                          NAN YA PLASTICS
# 192                          NAN YA PLASTICS
# 1475                         NAN YA PLASTICS
# 1375                        FORMOSA PLASTICS
# 1374                        FORMOSA PLASTICS
# 1270                         NAN YA PLASTICS
# 324               NANYA PLASTICS CORPORATION
# 1056                        FORMOSA PLASTICS
# 1679                        FORMOSA PLASTICS
# 371   FORMOSA CHEMICALS ANDFIBRE CORPORATION
# 1584                         NAN YA PLASTICS
# 320                         FORMOSA PLASTICS
# 601                          NAN YA PLASTICS
# 1319                   FORMOSA PETROCHEMICAL
#
#                                                    預測產品 預測產品使用方式  \
# 13                                           ['TAIWAN']     rule
# 1081                                 ['POLYESTER FILM']     rule
# 1393                   ['POLYESTER RESIN', 'PET RESIN']     rule
# 498                                ['TAIWAN', 'GASOIL']     rule
# 490                          ['POLYESTER STAPLE FIBER']     rule
# 1693                                          ['RESIN']     rule
# 1370                                   ['ACRYLIC ACID']     rule
# 1514                                      ['POLYESTER']     rule
# 875     ['ETHYLENEPROPYLENE COPOLYMER', 'YUNGSOX 3080']     rule
# 1725  ['BASE OIL 500N', 'BASE OIL 150N', 'BASE OIL 7...     rule
# 1690  ['ETHYLENEPROPYLENE COPOLYMER', 'YUNGSOX', ' P...     rule
# 1415                                ['AX4000', ' ABS ']     rule
# 325                                ['EPOXY RESIN NPEL']     rule
# 1083                                 ['POLYESTER FILM']     rule
# 762                          ['PVC SUSPENSION', ' PP ']     rule
# 1376                                          ['KGCFR']     bert
# 1163                                         ['TAIWAN']     rule
# 647       ['PVC RESIN S60', 'LAMINATE', ' PP ', ' PE ']     rule
# 506                                           ['NYLON']     rule
# 1087                  ['MONOETHYLENE GLYCOL', 'TAIWAN']     rule
# 1757                                 ['TAIWAN', 'DOTP']     rule
# 1664                     ['PLASTIC RESIN', 'PPCO 3015']     rule
# 1585                ['PVC CLEAR RIGID SHEET', 'TAIWAN']     rule
# 559   ['POLYESTER PARTIALLY ORIENTED YARN', 'TAIRILI...     rule
# 1381                         ['TAIWAN', ' PE ', 'ACID']     rule
# 1124                            ['NAN YA RELEASE FILM']     rule
# 996                                ['TAIWAN', 'TAISOX']     rule
# 283                               ['METHACRYLATE ACID']     rule
# 245                          ['EPOXIDIZED SOYBEAN OIL']     rule
# 192                                    ['SOYABEAN OIL']     rule
# 1475                                            ['MMA']     rule
# 1375                             ['PVC MASS RESIN B57']     rule
# 1374                           ['PVC SUSPENSION RESIN']     rule
# 1270                  ['NAN YA RELEASE FILM', 'TAIWAN']     rule
# 324                                ['EPOXY RESIN NPEL']     rule
# 1056                                         ['TAIWAN']     rule
# 1679                        ['TAIWAN', 'LLDPE', 'HDPE']     rule
# 371                                  ['TAIWAN', 'ACID']     rule
# 1584                                 ['BPA BISPHENOLA']     rule
# 320                       ['POLYOXYMETHYLENE', 'FM090']     rule
# 601                          ['EPOXIDIZED SOYBEAN OIL']     rule
# 1319  ['BASE OIL 500N', 'BASE OIL 150N', 'BASE OIL 7...     rule
#
#                             預測產品(取長度最長) 推薦公司事業部  \
# 13                               TAIWAN      27
# 1081                     POLYESTER FILM      25
# 1393                    POLYESTER RESIN     nan
# 498                              TAIWAN      60
# 490              POLYESTER STAPLE FIBER      02
# 1693                              RESIN      29
# 1370                       ACRYLIC ACID     nan
# 1514                          POLYESTER      25
# 875         ETHYLENEPROPYLENE COPOLYMER      1P
# 1725                      BASE OIL 500N      60
# 1690        ETHYLENEPROPYLENE COPOLYMER      1P
# 1415                             AX4000     nan
# 325                    EPOXY RESIN NPEL      02
# 1083                     POLYESTER FILM     nan
# 762                      PVC SUSPENSION      11
# 1376                              KGCFR      27
# 1163                             TAIWAN      18
# 647                       PVC RESIN S60      11
# 506                               NYLON      45
# 1087                MONOETHYLENE GLYCOL      25
# 1757                             TAIWAN      02
# 1664                      PLASTIC RESIN      11
# 1585              PVC CLEAR RIGID SHEET      02
# 559   POLYESTER PARTIALLY ORIENTED YARN      25
# 1381                             TAIWAN     nan
# 1124                NAN YA RELEASE FILM      2E
# 996                              TAIWAN      18
# 283                   METHACRYLATE ACID      12
# 245              EPOXIDIZED SOYBEAN OIL      24
# 192                        SOYABEAN OIL      24
# 1475                                MMA      2B
# 1375                 PVC MASS RESIN B57     nan
# 1374               PVC SUSPENSION RESIN     nan
# 1270                NAN YA RELEASE FILM      25
# 324                    EPOXY RESIN NPEL      02
# 1056                             TAIWAN      18
# 1679                             TAIWAN      18
# 371                              TAIWAN      48
# 1584                     BPA BISPHENOLA      28
# 320                    POLYOXYMETHYLENE      17
# 601              EPOXIDIZED SOYBEAN OIL      24
# 1319                      BASE OIL 500N      60
#
#                                   根據產品預測代號 利用公司名稱預測公司代號 集成預測代號  \
# 13                                  ['1P']     not find     1P
# 1081                          ['2E', '25']            2     2E
# 1393                    ['24', '25', '25']            2     25
# 498               ['1P', '60', '61', '61']            6     61
# 490                           ['25', '25']     not find     25
# 1693                          ['4A', '18']            2     25
# 1370                                ['12']            1     12
# 1514                          ['26', '42']            2     26
# 875                           ['4A', '18']            1     18
# 1725              ['60', '60', '61', '1P']            6     61
# 1690              ['4A', '18', '1P', '21']            1     18
# 1415                          ['4A', '4A']            4     4A
# 325                                 ['2R']     not find     2R
# 1083                          ['2E', '25']            2     2E
# 762                     ['11', '1P', '21']            1     1P
# 1376                                ['11']            2     24
# 1163                                ['1P']            1     1P
# 647   ['11', '2M', '28', '1P', '21', '21']            1     1P
# 506                           ['42', '45']            4     42
# 1087                    ['2A', '25', '1P']            2     2A
# 1757                    ['1P', '27', '27']     not find     27
# 1664        ['23', '4A', '11', '1P', '1P']            1     1P
# 1585                    ['23', '23', '1P']     not find     23
# 559               ['25', '25', '1P', '22']            2     22
# 1381        ['1P', '21', '48', '27', '1A']            4     48
# 1124                          ['26', '2E']            2     26
# 996                           ['1P', '18']            1     1P
# 283                           ['1A', '12']            1     1A
# 245                           ['2P', '24']            2     2P
# 192                     ['2P', '24', '22']            2     2P
# 1475                                ['1A']            2     22
# 1375                                ['11']            1     11
# 1374                                ['11']            1     11
# 1270                    ['26', '2E', '1P']            2     26
# 324                                 ['2R']     not find     2R
# 1056                                ['1P']            1     1P
# 1679        ['1P', '18', '18', '4A', '18']            1     1P
# 371               ['1P', '48', '27', '1A']     not find     1P
# 1584                          ['2P', '28']            2     2P
# 320                           ['1P', '1P']            1     1P
# 601                           ['2P', '24']            2     2P
# 1319              ['60', '60', '61', '1P']            6     61
#
#                    from
# 13             0927.xls
# 1081           1113.xls
# 1393           1126.xls
# 498            1020.xls
# 490            1020.xls
# 1693           1207.xls
# 1370           1126.xls
# 1514           1201.xls
# 875            1103.xls
# 1725           1207.xls
# 1690           1207.xls
# 1415           1126.xls
# 325            1012.xls
# 1083           1113.xls
# 762            1029.xls
# 1376           1126.xls
# 1163           1117.xls
# 647            1026.xls
# 506            1021.xls
# 1087           1113.xls
# 1757           1208.xls
# 1664           1206.xls
# 1585           1202.xls
# 559            1022.xls
# 1381           1126.xls
# 1124           1116.xls
# 996            1105.xls
# 283            1008.xls
# 245            1007.xls
# 192   1005(1004轉入).xlsx
# 1475           1130.xls
# 1375           1126.xls
# 1374           1126.xls
# 1270           1122.xls
# 324            1012.xls
# 1056           1109.xls
# 1679           1206.xls
# 371            1013.xls
# 1584           1202.xls
# 320            1012.xls
# 601            1023.xls
# 1319           1123.xls

# %%
df.loc[df['預測產品使用方式']=='bert']
# Out:
#                                                     45A  \
# 347                                             OTHERS
# 1376   POLYAMIDEQUANTITY 16000 KGSNAN YA PA6 2100HNC...
# 1401   STABILIZER LQX24PA 16000KG AT USD 297KGCIF NI...
# 1503   OTHERSRNINCOTERMSCIFPIPAVAV PORT INDIARNCONTR...
# 1528   PVC PROCESSING AND P301 8000KG AT USD 266KGPI...
# 1562    7560 KGS N 6 POY 9024 SNOW WHITE AA GRADE  A...
#
#                               受益人                                 預測產品  \
# 347              FORMOSA PLASTICS                           ['OTHERS']
# 1376              NAN YA PLASTICS                            ['KGCFR']
# 1401              NAN YA PLASTICS                  ['CHINASTABILIZER']
# 1503             FORMOSA PLASTICS  ['PORT INDIARNCONTRACTDETAILSRNPI']
# 1528             FORMOSA PLASTICS                        ['PORTCHINA']
# 1562  FORMOSA CHEMICALS AND FIBRE                            ['WHITE']
#
#      預測產品使用方式                      預測產品(取長度最長) 推薦公司事業部 根據產品預測代號 利用公司名稱預測公司代號  \
# 347      bert                           OTHERS     nan   ['29']            1
# 1376     bert                            KGCFR      27   ['11']            2
# 1401     bert                  CHINASTABILIZER      24   ['2P']            2
# 1503     bert  PORT INDIARNCONTRACTDETAILSRNPI      11   ['42']            1
# 1528     bert                        PORTCHINA      11   ['25']            1
# 1562     bert                            WHITE      45   ['14']            4
#
#      集成預測代號      from
# 347      1B  1013.xls
# 1376     24  1126.xls
# 1401     2P  1126.xls
# 1503     1P  1201.xls
# 1528     17  1201.xls
# 1562     4H  1202.xls

# %%
error_test = pd.read_csv('../data/測試數據/0927到1210.csv',index_col=0).reset_index(drop=True).loc[df.index]
print(error_test.shape)
error_test.head()
# Out:
# (181, 21)
#      項次   電文代號  銀行                20  回傳代碼                       回傳訊息  \
# 13   27  mt700  16  HNITF2126730242I   200  {"MESSAGE":"","CODE":200}
# 74   59  mt700  A5     230-612-00016   200  {"MESSAGE":"","CODE":200}
# 83   69  mt700  A5      ILC749030834   200  {"MESSAGE":"","CODE":200}
# 88   76  mt700  A5  OBLA1MU0009-0560   200  {"MESSAGE":"","CODE":200}
# 137  72  mt700  A5  F1BG2/00051/1405   200  {"MESSAGE":"","CODE":200}
#
#                     建檔日期                                                受益人  \
# 13   2021/09/24 12:40:19  NANYA PLASTICS CORPORATION\n201 TUNG HWA N.ROA...
# 74   2021/09/27 11:06:17  NAN YA PLASTICS CORPORATION\n201, TUNG HWA N.R...
# 83   2021/09/27 12:19:26  FORMOSA PETROCHEMICAL CORPORATION\nROOM 510, 5...
# 88   2021/09/27 14:51:29  FORMOSA PETROCHEMICAL CORPORATION\nROOM 510,5F...
# 137  2021/09/28 11:01:21  FORMOSA PLASTICS CORPORATION\nNO.201 TUNG HWA ...
#
#                  金額 推薦公司事業部  ... MEMO      from  \
# 13      USD38400,00      27  ...  NaN  0927.xls
# 74       USD120000,      28  ...  NaN  0928.xls
# 83     USD62000000,      60  ...  NaN  0928.xls
# 88   USD24300000,00      60  ...  NaN  0928.xls
# 137     USD64250,00      18  ...  NaN  0929.xls
#
#                                                    45A  \
# 13   + COMMODITY: DPHP\r\n+ TOTAL QUANTITY: 16MTS\r...
# 74            GLASS FABRICS\r\n.\r\nCIF JAPANESE PORTS
# 83   750,000 BARRELS PLUS/MINUS 10 PCT OF GASOIL 10...
# 88   300,000 BBLS (+/-10PCT) OF GASOIL 0.05PCT S\r\...
# 137  FOB ANY SEAPORT IN TAIWAN\r\nEVA 7350M VIRGIN ...
#
#                                                     50  \
# 13   SINO VIET NAM COMPANY LIMITED\r\nLIEN PHUONG I...
# 74   TSUKASA SERVICE CO., LTD.\r\n2-22, MORIMOTO 4-...
# 83   GLENCORE SINGAPORE PTE LTD\r\nHEX 34-01 MILLEN...
# 88   WINSON OIL BUNKERING PTE LTD.\r\n1 RAFFLES PLA...
# 137  YURAK INTERNATIONAL TRADING CO.,LTD\r\n19F-2,N...
#
#                                                     59  \
# 13   NANYA PLASTICS CORPORATION\r\n201 TUNG HWA N.R...
# 74   NAN YA PLASTICS CORPORATION\r\n201, TUNG HWA N...
# 83   FORMOSA PETROCHEMICAL CORPORATION\r\nROOM 510,...
# 88   FORMOSA PETROCHEMICAL CORPORATION\r\nROOM 510,...
# 137  FORMOSA PLASTICS CORPORATION\r\nNO.201 TUNG HW...
#
#                                                    46A  \
# 13   1. SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS I...
# 74   + SIGNED COMMERCIAL INVOICE IN ONE ORIGINAL AN...
# 83   AVAILABLE WITH ADVISING BANK BY NEGOTIATION AT...
# 88   1.SIGNED PROVISIONAL/COMMERCIAL INVOICE IN DUP...
# 137  + SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND ...
#
#                                                    47A  \
# 13   1. ALL REQUIRED DOCUMENTS AND ITS ATTACHED LIS...
# 74   + REIMBURSEMENT BY TELECOMMUNICATION IS PROHIB...
# 83   1. PHOTOCOPIES IN LIEU OF COPY DOCUMENTS ARE A...
# 88   1.INSURANCE TO BE COVERED BY APPLICANT.\r\n2.C...
# 137  + THE NUMBER AND THE DATE OF THE CREDIT AND TH...
#
#                                                     78 memo  Unnamed: 5
# 13   1. USD88.00 OF DISCREPANCY FEE PLUS USD38.50 O...  NaN         NaN
# 74   + ANY DRAWING AMOUNTS MUST BE ENDORSED ON THE ...  NaN         NaN
# 83   1.DOCUMENTS TO BE COURIERED IN 01 LOT TO MIZUH...  NaN         NaN
# 88   A.ALL NEGOTIABLE DOCS MUST BE SENT BY COURIER ...  NaN         NaN
# 137  ON RECEIPT OF DOCUMENTS CONFORMING TO THE TERM...  NaN         NaN
#
# [5 rows x 21 columns]

# %%
error_test.to_csv('../data/測試數據/錯誤預測.csv')
print(df.shape)
print(error_test.shape)
# Out:
# (181, 10)
# (181, 21)

# %%
idx_list = []
for idx in df.index:
    # 條件1 只有一個代碼 且 第一碼跟公司第一碼一模一樣
    cond1 = (len(df.loc[idx,'根據產品預測代號']) == 6)&(str(df.loc[idx,'推薦公司事業部'][0]) == str(df.loc[idx,'利用公司名稱預測公司代號'][0]))
    # 條件2 預測出 []
    cond2 = (len(df.loc[idx,'根據產品預測代號']) == 2)
    if cond1 | cond2:
        idx_list.append(idx)
print(len(idx_list))
# Out:
# 22

# %%
df = df.loc[idx_list]
print(df.shape)
df
# Out:
# (22, 10)
#                                                     45A  \
# 401    14 BUNTANEDIOL QTY 6000 MT AT THE RATE USD 46...
# 628    ITEM     QUANTITY UNIT PRICE AMOUNT      KG  ...
# 750    FOB ANY PORT IN TAIWANEVA 7470M PRIME VIRGIN ...
# 784    TERMS OF PRICE FOB KAOHSIUNGCOUNTRY OF ORIGIN...
# 998    20 MT DOAAT USD 230000MTTOTAL AMOUNT  USD 460...
# 1022                 CFR ANY JAPANESE PORTRNABS AF3510
# 1056   FOB ANY PORT IN TAIWANEVA 7350M PRIME GRADE 5...
# 1163   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 1212   TERMS OF PRICE CFRDOPAS PER PROFORMA INVOICE ...
# 1343   COMMODITY 911PQUANTITY 32MTUNIT PRICE USD2525...
# 1344   AABS AG15A1 QUANTITY2500MT UNIT PRICEUSD21900...
# 1376   POLYAMIDEQUANTITY 16000 KGSNAN YA PA6 2100HNC...
# 1398   SALES CONTRACT 90006559 PO 90006559DESCRIPTIO...
# 1401   STABILIZER LQX24PA 16000KG AT USD 297KGCIF NI...
# 1407   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 1475   DOORS AND FRAMES FIBERGLASS AND ACCESSORIESCF...
# 1503   OTHERSRNINCOTERMSCIFPIPAVAV PORT INDIARNCONTR...
# 1507   INQUIRY NO18K21111905 ITEM QUANTITYMTS  UNIT ...
# 1528   PVC PROCESSING AND P301 8000KG AT USD 266KGPI...
# 1562    7560 KGS N 6 POY 9024 SNOW WHITE AA GRADE  A...
# 1724   NO COMMODITY QUANTITY  UNIT PRICE AMOUNT   MT...
# 1841   TRADE TERM FOB MAILIAO PORT TAIWANCAUSTIC SOD...
#
#                               受益人                                 預測產品  \
# 401               NAN YA PLASTICS                              ['EVA']
# 628               NAN YA PLASTICS                           ['TAIWAN']
# 750              FORMOSA PLASTICS                           ['TAIWAN']
# 784   FORMOSA CHEMICALS AND FIBRE                           ['TAIWAN']
# 998               NAN YA PLASTICS                           ['TAIWAN']
# 1022  FORMOSA CHEMICALS AND FIBRE                         ['JAPANESE']
# 1056             FORMOSA PLASTICS                           ['TAIWAN']
# 1163             FORMOSA PLASTICS                           ['TAIWAN']
# 1212              NAN YA PLASTICS                           ['TAIWAN']
# 1343              NAN YA PLASTICS                           ['TAIWAN']
# 1344  FORMOSA CHEMICALS AND FIBRE                           ['TAIWAN']
# 1376              NAN YA PLASTICS                            ['KGCFR']
# 1398              NAN YA PLASTICS                         ['2100ANC1']
# 1401              NAN YA PLASTICS                  ['CHINASTABILIZER']
# 1407             FORMOSA PLASTICS                           ['TAIWAN']
# 1475              NAN YA PLASTICS                              ['MMA']
# 1503             FORMOSA PLASTICS  ['PORT INDIARNCONTRACTDETAILSRNPI']
# 1507             FORMOSA PLASTICS                           ['TAIWAN']
# 1528             FORMOSA PLASTICS                        ['PORTCHINA']
# 1562  FORMOSA CHEMICALS AND FIBRE                            ['WHITE']
# 1724             FORMOSA PLASTICS                              ['EVA']
# 1841             FORMOSA PLASTICS                           ['TAIWAN']
#
#      預測產品使用方式                      預測產品(取長度最長) 推薦公司事業部 根據產品預測代號 利用公司名稱預測公司代號  \
# 401      rule                              EVA      2P   ['12']            2
# 628      rule                           TAIWAN      25   ['1P']            2
# 750      rule                           TAIWAN      18   ['1P']            1
# 784      rule                           TAIWAN      4A   ['1P']            4
# 998      rule                           TAIWAN      28   ['1P']            2
# 1022     rule                         JAPANESE      4A   ['21']            4
# 1056     rule                           TAIWAN      18   ['1P']            1
# 1163     rule                           TAIWAN      18   ['1P']            1
# 1212     rule                           TAIWAN      27   ['1P']            2
# 1343     rule                           TAIWAN      27   ['1P']            2
# 1344     rule                           TAIWAN      4A   ['1P']            4
# 1376     bert                            KGCFR      27   ['11']            2
# 1398     rule                         2100ANC1      24   ['23']            2
# 1401     bert                  CHINASTABILIZER      24   ['2P']            2
# 1407     rule                           TAIWAN      18   ['1P']            1
# 1475     rule                              MMA      2B   ['1A']            2
# 1503     bert  PORT INDIARNCONTRACTDETAILSRNPI      11   ['42']            1
# 1507     rule                           TAIWAN      17   ['1P']            1
# 1528     bert                        PORTCHINA      11   ['25']            1
# 1562     bert                            WHITE      45   ['14']            4
# 1724     rule                              EVA      17   ['12']            1
# 1841     rule                           TAIWAN      11   ['1P']            1
#
#      集成預測代號               from
# 401      2R  1018(1015-16).xls
# 628      2G           1026.xls
# 750      1P           1028.xls
# 784      45           1029.xls
# 998      26           1108.xls
# 1022     42           1109.xls
# 1056     1P           1109.xls
# 1163     1P           1117.xls
# 1212     2P           1118.xls
# 1343     29           1125.xls
# 1344     45           1125.xls
# 1376     24           1126.xls
# 1398     23           1126.xls
# 1401     2P           1126.xls
# 1407     1P           1126.xls
# 1475     22           1130.xls
# 1503     1P           1201.xls
# 1507     1P           1201.xls
# 1528     17           1201.xls
# 1562     4H           1202.xls
# 1724     12           1207.xls
# 1841     1P           1210.xls

# %%
import numpy as np
寶典by_ricky = pd.DataFrame()
寶典by_ricky['CODIV'] = df['推薦公司事業部']
寶典by_ricky['DIVNM'] = np.nan
寶典by_ricky['ITEMNM'] = df['預測產品(取長度最長)']
寶典by_ricky['memo'] = 'ricky + der'
print(寶典by_ricky.shape)
寶典by_ricky
# Out:
# (22, 4)
#      CODIV  DIVNM                           ITEMNM         memo
# 401     2P    NaN                              EVA  ricky + der
# 628     25    NaN                           TAIWAN  ricky + der
# 750     18    NaN                           TAIWAN  ricky + der
# 784     4A    NaN                           TAIWAN  ricky + der
# 998     28    NaN                           TAIWAN  ricky + der
# 1022    4A    NaN                         JAPANESE  ricky + der
# 1056    18    NaN                           TAIWAN  ricky + der
# 1163    18    NaN                           TAIWAN  ricky + der
# 1212    27    NaN                           TAIWAN  ricky + der
# 1343    27    NaN                           TAIWAN  ricky + der
# 1344    4A    NaN                           TAIWAN  ricky + der
# 1376    27    NaN                            KGCFR  ricky + der
# 1398    24    NaN                         2100ANC1  ricky + der
# 1401    24    NaN                  CHINASTABILIZER  ricky + der
# 1407    18    NaN                           TAIWAN  ricky + der
# 1475    2B    NaN                              MMA  ricky + der
# 1503    11    NaN  PORT INDIARNCONTRACTDETAILSRNPI  ricky + der
# 1507    17    NaN                           TAIWAN  ricky + der
# 1528    11    NaN                        PORTCHINA  ricky + der
# 1562    45    NaN                            WHITE  ricky + der
# 1724    17    NaN                              EVA  ricky + der
# 1841    11    NaN                           TAIWAN  ricky + der

# %%
寶典by_ricky.to_excel('../data/寶典/寶典人工處理後/寶典_by_ricky.xlsx',index=False)
寶典by_ricky.to_excel('../output/寶典_by_ricky.xlsx',index=False)

# %%
#ok
