# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
df = pd.read_excel('../predict_result/0927到1210測試結果.xlsx').astype(str)
print(df.columns)
df = df.loc[df['錯誤原因']!='無錯誤',['45A','受益人','預測產品','預測產品使用方式','預測產品(取長度最長)','推薦公司事業部','根據產品預測代號','利用公司名稱預測公司代號','集成預測代號','from']]
print(df.shape)
display(df.sample(42))
df.to_excel('../output/錯誤型態彙整.xlsx')
# Out:
# Index(['45A', '項次', '電文代號', '銀行', '20', '回傳代碼', '回傳訊息', '建檔日期', '受益人', '金額',
#        '推薦公司事業部', '是否已轉MIS', 'MEMO', 'from', '50', '59', '46A', '47A', '78',
#        'memo', 'Unnamed: 5', '預測產品', '預測產品(取長度最長)', '預測產品使用方式', '根據產品預測部門',
#        '根據產品預測代號', '預測開狀人', '利用公司名稱預測公司代號', 'DIVSION', 'DIVSION預測代號', '集成預測代號',
#        '銀行輸入', '開狀銀行', '正確與否', '錯誤原因', 'EXPNO'],
#       dtype='object')
# (233, 10)
#                                                     45A  \
# 1790   1 TERMS CIF JAKARTA PORT INDONESIA INCOTERMS ...
# 838    COUNTRY OF ORIGIN TAIWANPRICE TERMS CIF SOUTH...
# 750    FOB ANY PORT IN TAIWANEVA 7470M PRIME VIRGIN ...
# 245    54 MT OF EPOXIDIZED SOYBEAN OIL ESO132 AT USD...
# 286    TAIRILIN BRAND PET CHIPS B GRADEJNNC 1710000K...
# 1115       CIF JAPAN MAIN PORT OR AIRPORTGLASS FABRICS
# 1408   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 464    COMMODITYMONOETHYLENE GLYCOLMEG FIBER GRADEUN...
# 1388   QTY 1800 MT OF TAIRISAN SAN RESINSGRADE NO NF...
# 1728   300000 BBLS 10PCT OF GASOIL 005PCT SCOUNTRY O...
# 499    EVA TAISOX 7470M 24MTS USD3845MTCIF CAT LAI P...
# 1293   DELIVERY TERMS CIF VALENCIA PORT SPAIN INCOTM...
# 1160   COMMODITY MONOETHYLENE GLYCOL MEG FIBER GRADE...
# 523    1 LLDPE 3490QUANTITY 75 MTUNIT PRICE USD1350M...
# 1396    PLASTIC RESIN CIF CHATTOGRAM BANGLADESH1 1 X...
# 1838   COMMODITY MONOETHYLENE GLYCOL MEG FIBER GRADE...
# 324    EPOXY RESIN NPEL127HBENEFICIARY MUST CERTIFY ...
# 1834   POLYPROPYLENE RESIN GRADE NOK1035QUANTITY 25 ...
# 243    300000 BBLS 10PCT OF GASOIL 10PPMCOUNTRY OF O...
# 1375   525 MT OF PVC MASS RESIN B57 AT A UNIT PRICE ...
# 700    COMMODITY PP SYNTHETIC PAPER BCD 04E 02MM X 1...
# 1317   EVA TAISOX7360M 15000 KG EVA TAISOX7470M 1500...
# 779    COVERING 100 PERCENT OF INVOICE VALUE OF GOOD...
# 276           EVA TAISOX 7240M CIF PORT KLANG MALAYSIA
# 1656   1 COMMODITY POLYPROPYLENE GRADE K10112 TOTAL ...
# 717    HDPE 8010  QTY 100 MT AT USD1150MTFOB ANY POR...
# 192    EPOXIDIZED SOYABEAN OIL ESO132X QUANTITY 18MT...
# 762    32MTS OF PVC SUSPENSION S65 AT USD1660MTTOTAL...
# 1622   75 MT POLYPROPYLENE HOMOPOLYMER S1005 RAFFIA ...
# 1467   2500000 KGS EVA 7470K AT USD445KGHS CODE 3901...
# 763    CIF TOKYOJAPANPOLYETHYLENE TEREPHTHALATE PET ...
# 646    COMMODITYPVC RESINS60QUANTITY1085MTUNIT PRICE...
# 849           EVA TAISOX 7240M CIF PORT KLANG MALAYSIA
# 283    PRODUCT METHACRYLATE ACIDQUANTITY 1560000 KGS...
# 684    1600 MT OF EPOXIDIZED SOYBEAN OILAT THE RATE ...
# 1547   1COMMODITY EVA TAISOX 7470MQUANTITY 210MTUNIT...
# 1624   EVA TAISOX 7470M 72MT X USD3695MTCIF SHATIAN ...
# 1374   PVC SUSPENSION RESIN S65D 25KG BAGS QTY 36 MT...
# 1816   EVA 7350M 50 MT AT USD3195MTLLDPE 3224 19 MT ...
# 969    PRICE TERM C I F HONG KONGPA6 100PER CENT PRE...
# 1559   PRICE TERM C I F HAIPHONG VIETNAMPLASTIC RESI...
# 93     TAISOX EVA 7350MQUANTITY 5500MTUNIT PRICE USD...
#
#                                           受益人  \
# 1790                         FORMOSA PLASTICS
# 838                NANYA PLASTICS CORPORATION
# 750                          FORMOSA PLASTICS
# 245                           NAN YA PLASTICS
# 286                           NAN YA PLASTICS
# 1115                          NAN YA PLASTICS
# 1408                         FORMOSA PLASTICS
# 464                           NAN YA PLASTICS
# 1388              FORMOSA CHEMICALS AND FIBRE
# 1728                    FORMOSA PETROCHEMICAL
# 499                          FORMOSA PLASTICS
# 1293              FORMOSA CHEMICALS AND FIBRE
# 1160                          NAN YA PLASTICS
# 523                          FORMOSA PLASTICS
# 1396              FORMOSA CHEMICALS AND FIBRE
# 1838                          NAN YA PLASTICS
# 324                NANYA PLASTICS CORPORATION
# 1834   FORMOSA CHEMICALS ANDFIBRE CORPORATION
# 243                     FORMOSA PETROCHEMICAL
# 1375                         FORMOSA PLASTICS
# 700                           NAN YA PLASTICS
# 1317                         FORMOSA PLASTICS
# 779               FORMOSA CHEMICALS AND FIBRE
# 276                          FORMOSA PLASTICS
# 1656  FORMOSA CHEMICALS AND  FIBRECORPORATION
# 717                          FORMOSA PLASTICS
# 192                           NAN YA PLASTICS
# 762                          FORMOSA PLASTICS
# 1622          FORMOSA CHEMICALS ad FIBRE CORP
# 1467                         FORMOSA PLASTICS
# 763                           NAN YA PLASTICS
# 646                          FORMOSA PLASTICS
# 849                          FORMOSA PLASTICS
# 283                          FORMOSA PLASTICS
# 684                           NAN YA PLASTICS
# 1547                         FORMOSA PLASTICS
# 1624                         FORMOSA PLASTICS
# 1374                         FORMOSA PLASTICS
# 1816                         FORMOSA PLASTICS
# 969               FORMOSA CHEMICALS AND FIBRE
# 1559                         FORMOSA PLASTICS
# 93                           FORMOSA PLASTICS
#
#                                                    預測產品 預測產品使用方式  \
# 1790            ['PVC COPOLYMER', 'FORMOLON', 'TAIWAN']     rule
# 838            ['PVC CLEAR RIGID SHEET', 'TAIWANPRICE']     rule
# 750                                          ['TAIWAN']     rule
# 245                          ['EPOXIDIZED SOYBEAN OIL']     rule
# 286              ['TAIRILIN BRAND PET CHIPS', 'TAIWAN']     rule
# 1115                                  ['GLASS FABRICS']     rule
# 1408                                         ['TAIWAN']     rule
# 464                   ['MONOETHYLENE GLYCOL', 'TAIWAN']     rule
# 1388                            ['TAIRISAN SAN RESINS']     rule
# 1728                               ['TAIWAN', 'GASOIL']     rule
# 499             ['TAISOX 7470M', 'EVA TAISOX', ' EVA ']     rule
# 1293  ['DOPE DYED BLACK', 'COVERING', 'NYLON 6', 'YA...     rule
# 1160                  ['MONOETHYLENE GLYCOL', 'TAIWAN']     rule
# 523                        ['TAIWAN', ' EVA ', 'LLDPE']     rule
# 1396  ['ACRYLONITRILE BUTADIENE STYRENE', 'PLASTIC R...     rule
# 1838             ['MONOETHYLENE GLYCOL', 'TAIWANPRICE']     rule
# 324                                ['EPOXY RESIN NPEL']     rule
# 1834                      ['POLYPROPYLENE RESIN GRADE']     rule
# 243                                ['TAIWAN', 'GASOIL']     rule
# 1375                             ['PVC MASS RESIN B57']     rule
# 700            ['PP SYNTHETIC PAPER', 'TAIWAN', ' PP ']     rule
# 1317                            ['EVA TAISOX', ' EVA ']     rule
# 779                  ['SAN RESIN', 'COVERING', ' SAN ']     rule
# 276                             ['EVA TAISOX', ' EVA ']     rule
# 1656               ['POLYPROPYLENE', 'TAIWAN', 'K1011']     rule
# 717                                  ['TAIWAN', 'HDPE']     rule
# 192                                    ['SOYABEAN OIL']     rule
# 762                          ['PVC SUSPENSION', ' PP ']     rule
# 1622                                  ['POLYPROPYLENE']     rule
# 1467                                ['TAIWAN', ' EVA ']     rule
# 763          ['POLYETHYLENE', 'PET RESIN', 'PHTHALATE']     rule
# 646        ['PVC RESINS60', 'LAMINATE', ' PE ', ' PP ']     rule
# 849                             ['EVA TAISOX', ' EVA ']     rule
# 283                               ['METHACRYLATE ACID']     rule
# 684                          ['EPOXIDIZED SOYBEAN OIL']     rule
# 1547  ['TAISOX 7470M', 'EVA TAISOX', 'TAIWAN', ' EVA ']     rule
# 1624            ['TAISOX 7470M', 'EVA TAISOX', ' EVA ']     rule
# 1374                           ['PVC SUSPENSION RESIN']     rule
# 1816                       ['TAIWAN', ' EVA ', 'LLDPE']     rule
# 969                                           ['NYLON']     rule
# 1559             ['PLASTIC RESIN', 'PPCO 3015', ' PP ']     rule
# 93                              ['TAISOX EVA', ' EVA ']     rule
#
#                           預測產品(取長度最長) 推薦公司事業部  \
# 1790                    PVC COPOLYMER      11
# 838             PVC CLEAR RIGID SHEET      02
# 750                            TAIWAN      18
# 245            EPOXIDIZED SOYBEAN OIL      24
# 286          TAIRILIN BRAND PET CHIPS      2E
# 1115                    GLASS FABRICS      28
# 1408                           TAIWAN     nan
# 464               MONOETHYLENE GLYCOL      2A
# 1388              TAIRISAN SAN RESINS     nan
# 1728                           TAIWAN      60
# 499                      TAISOX 7470M      18
# 1293                  DOPE DYED BLACK      45
# 1160              MONOETHYLENE GLYCOL      2A
# 523                            TAIWAN      18
# 1396  ACRYLONITRILE BUTADIENE STYRENE     nan
# 1838              MONOETHYLENE GLYCOL      2A
# 324                  EPOXY RESIN NPEL      02
# 1834        POLYPROPYLENE RESIN GRADE      4A
# 243                            TAIWAN      60
# 1375               PVC MASS RESIN B57     nan
# 700                PP SYNTHETIC PAPER      23
# 1317                       EVA TAISOX      18
# 779                         SAN RESIN      42
# 276                        EVA TAISOX      18
# 1656                    POLYPROPYLENE      4A
# 717                            TAIWAN      18
# 192                      SOYABEAN OIL      24
# 762                    PVC SUSPENSION      11
# 1622                    POLYPROPYLENE      4A
# 1467                           TAIWAN      18
# 763                      POLYETHYLENE      2E
# 646                      PVC RESINS60      11
# 849                        EVA TAISOX      18
# 283                 METHACRYLATE ACID      12
# 684            EPOXIDIZED SOYBEAN OIL      24
# 1547                     TAISOX 7470M      18
# 1624                     TAISOX 7470M      18
# 1374             PVC SUSPENSION RESIN     nan
# 1816                           TAIWAN      18
# 969                             NYLON      45
# 1559                    PLASTIC RESIN      11
# 93                         TAISOX EVA      18
#
#                                                根據產品預測代號 利用公司名稱預測公司代號 集成預測代號  \
# 1790                     ['11', '18', '2P', '11', '1P']            1     1P
# 838                                  ['23', '23', '17']     not find     23
# 750                                              ['1P']            1     1P
# 245                                        ['2P', '24']            2     2P
# 286                                  ['25', '25', '1P']            2     25
# 1115                                       ['2G', '28']            2     2G
# 1408                                             ['1P']            1     1P
# 464                                  ['2A', '25', '1P']            2     25
# 1388                                             ['4A']            4     4A
# 1728                           ['1P', '60', '61', '61']            6     61
# 499                ['18', '18', '18', '18', '2P', '17']            1     17
# 1293  ['25', '17', '45', '25', 'XU', '45', '42', '12...            4     42
# 1160                                 ['2A', '25', '1P']            2     25
# 523          ['1P', '18', '18', '2P', '17', '18', '18']            1     17
# 1396                     ['4A', '23', '4A', '11', '1P']            4     4A
# 1838                                 ['2A', '25', '17']            2     25
# 324                                              ['2R']     not find     2R
# 1834                                       ['1P', '4A']     not find     1P
# 243                            ['1P', '60', '61', '61']            6     61
# 1375                                             ['11']            1     11
# 700                            ['23', '1P', '1P', '21']            2     21
# 1317                     ['18', '18', '18', '2P', '17']            1     17
# 779                                  ['4A', '17', '4A']            4     4A
# 276                      ['18', '18', '18', '2P', '17']            1     17
# 1656                           ['1P', '4A', '1P', '4A']     not find     1P
# 717                                  ['1P', '4A', '18']            1     1P
# 192                                  ['2P', '24', '22']            2     2P
# 762                                  ['11', '1P', '21']            1     1P
# 1622                                       ['1P', '4A']     not find     1P
# 1467                     ['1P', '18', '18', '2P', '17']            1     17
# 763                      ['18', '25', '25', '27', '2E']            2     25
# 646                ['11', '2M', '28', '21', '1P', '21']            1     1P
# 849                      ['18', '18', '18', '2P', '17']            1     17
# 283                                        ['1A', '12']            1     1A
# 684                                        ['2P', '24']            2     2P
# 1547         ['18', '18', '1P', '18', '18', '2P', '17']            1     17
# 1624               ['18', '18', '18', '18', '2P', '17']            1     17
# 1374                                             ['11']            1     11
# 1816         ['1P', '18', '18', '2P', '17', '18', '18']            1     17
# 969                                        ['42', '45']            4     42
# 1559         ['23', '4A', '11', '1P', '1P', '1P', '21']            1     1P
# 93                       ['18', '18', '18', '2P', '17']            1     17
#
#                    from
# 1790           1209.xls
# 838            1102.xls
# 750            1028.xls
# 245            1007.xls
# 286            1008.xls
# 1115           1116.xls
# 1408           1126.xls
# 464            1020.xls
# 1388           1126.xls
# 1728           1207.xls
# 499            1020.xls
# 1293           1123.xls
# 1160           1117.xls
# 523            1021.xls
# 1396           1126.xls
# 1838           1210.xls
# 324            1012.xls
# 1834           1210.xls
# 243            1006.xls
# 1375           1126.xls
# 700            1027.xls
# 1317           1123.xls
# 779            1029.xls
# 276            1007.xls
# 1656           1206.xls
# 717            1028.xls
# 192   1005(1004轉入).xlsx
# 762            1029.xls
# 1622           1203.xls
# 1467           1129.xls
# 763            1029.xls
# 646            1026.xls
# 849            1102.xls
# 283            1008.xls
# 684            1027.xls
# 1547           1201.xls
# 1624           1203.xls
# 1374           1126.xls
# 1816           1210.xls
# 969            1105.xls
# 1559           1202.xls
# 93             0929.xls

# %%
df.loc[df['預測產品使用方式']=='bert']
# Out:
#           45A               受益人        預測產品 預測產品使用方式 預測產品(取長度最長) 推薦公司事業部  \
# 347   OTHERS   FORMOSA PLASTICS  ['OTHERS']     bert      OTHERS     nan
#
#     根據產品預測代號 利用公司名稱預測公司代號 集成預測代號      from
# 347   ['29']            1     17  1013.xls

# %%
error_test = pd.read_csv('../data/測試數據/0927到1210.csv',index_col=0).reset_index(drop=True).loc[df.index]
print(error_test.shape)
error_test.head()
# Out:
# (233, 21)
#     項次   電文代號  銀行                20  回傳代碼                       回傳訊息  \
# 13  27  mt700  16  HNITF2126730242I   200  {"MESSAGE":"","CODE":200}
# 74  59  mt700  A5     230-612-00016   200  {"MESSAGE":"","CODE":200}
# 75  60  mt700  A5    363010108163-L   200  {"MESSAGE":"","CODE":200}
# 79  65  mt700  A5  868ISTN212690002   200  {"MESSAGE":"","CODE":200}
# 80  66  mt700  A5  869ISTN212690004   200  {"MESSAGE":"","CODE":200}
#
#                    建檔日期                                                受益人  \
# 13  2021/09/24 12:40:19  NANYA PLASTICS CORPORATION\n201 TUNG HWA N.ROA...
# 74  2021/09/27 11:06:17  NAN YA PLASTICS CORPORATION\n201, TUNG HWA N.R...
# 75  2021/09/27 11:58:49  FORMOSA PLASTICS CORPORATION\n201, TUNG HWA N....
# 79  2021/09/27 10:55:46      FORMOSA PLASTICS CORPORATION\nADDRESS SEE 47A
# 80  2021/09/27 10:56:35  FORMOSA PLASTICS CORPORATION\n8F,201,TUNG HWA ...
#
#              金額 推薦公司事業部  ... MEMO      from  \
# 13  USD38400,00      27  ...  NaN  0927.xls
# 74   USD120000,      28  ...  NaN  0928.xls
# 75  USD1992030,      18  ...  NaN  0928.xls
# 79   USD158500,      18  ...  NaN  0928.xls
# 80   USD514875,      18  ...  NaN  0928.xls
#
#                                                   45A  \
# 13  + COMMODITY: DPHP\r\n+ TOTAL QUANTITY: 16MTS\r...
# 74           GLASS FABRICS\r\n.\r\nCIF JAPANESE PORTS
# 75  +1) LLDPE 3470   240 MTS    USD 1,240/MT (H0FR...
# 79  CONTRACT NO.: H0LR37\r\nCOMMODITY: EVA TAISOX ...
# 80  EVA TAISOX 7350M\r\nQUANTITY: 75.00MTS UNIT PR...
#
#                                                    50  \
# 13  SINO VIET NAM COMPANY LIMITED\r\nLIEN PHUONG I...
# 74  TSUKASA SERVICE CO., LTD.\r\n2-22, MORIMOTO 4-...
# 75  Y AND M INTERNATIONAL CORP.\r\n11FL., NO.103, ...
# 79  XIAMEN HAIAO SUPPLY CHAIN\r\nSERVICE CO LTD\r\...
# 80  KINGFA SCI. AND TECH CO.,LTD\r\nNO.33 KEFENG R...
#
#                                                    59  \
# 13  NANYA PLASTICS CORPORATION\r\n201 TUNG HWA N.R...
# 74  NAN YA PLASTICS CORPORATION\r\n201, TUNG HWA N...
# 75  FORMOSA PLASTICS CORPORATION\r\n201, TUNG HWA ...
# 79    FORMOSA PLASTICS CORPORATION\r\nADDRESS SEE 47A
# 80  FORMOSA PLASTICS CORPORATION\r\n8F,201,TUNG HW...
#
#                                                   46A  \
# 13  1. SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS I...
# 74  + SIGNED COMMERCIAL INVOICE IN ONE ORIGINAL AN...
# 75  + MARINE BILLS OF LADING IN 1 NON-NEGOTIABLE C...
# 79  +SIGNED COMMERCIAL INVOICE IN 2 ORIGINALS INDI...
# 80  +SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS INDI...
#
#                                                   47A  \
# 13  1. ALL REQUIRED DOCUMENTS AND ITS ATTACHED LIS...
# 74  + REIMBURSEMENT BY TELECOMMUNICATION IS PROHIB...
# 75  + EACH SET OF DOCUMENTS PRESENTED WITH DISCREP...
# 79  +APPLICANT'S ADDRESS:19F, HAICANG BUSINESS BUI...
# 80  +GOODS NATURE: PLASTIC RAW MATERIALS\r\n+ALL D...
#
#                                                    78 memo  Unnamed: 5
# 13  1. USD88.00 OF DISCREPANCY FEE PLUS USD38.50 O...  NaN         NaN
# 74  + ANY DRAWING AMOUNTS MUST BE ENDORSED ON THE ...  NaN         NaN
# 75  DOCUMENTS TO BE DESPATCHED TO STANDARD CHARTER...  NaN         NaN
# 79  +TO NEGOTIATING BANK ONLY : PLEASE FORWARD ALL...  NaN         NaN
# 80  +TO NEGOTIATING BANK ONLY : PLEASE FORWARD ALL...  NaN         NaN
#
# [5 rows x 21 columns]

# %%
error_test.to_csv('../data/測試數據/錯誤預測.csv')
print(df.shape)
print(error_test.shape)
# Out:
# (233, 10)
# (233, 21)

# %%
idx_list = []
for idx in df.index:
    # 條件1 只有一個代碼 且 第一碼跟公司第一碼一模一樣
    cond1 = (len(df.loc[idx,'根據產品預測代號']) == 6)&(str(df.loc[idx,'推薦公司事業部'][0]) == str(df.loc[idx,'利用公司名稱預測公司代號'][0]))
    # 條件2 預測出 []
    cond2 = (len(df.loc[idx,'根據產品預測代號']) == 2)
    if cond1 | cond2:
        idx_list.append(idx)
print(len(idx_list))
# Out:
# 11

# %%
df = df.loc[idx_list]
print(df.shape)
df
# Out:
# (11, 10)
#                                                     45A  \
# 401    14 BUNTANEDIOL QTY 6000 MT AT THE RATE USD 46...
# 628    ITEM     QUANTITY UNIT PRICE AMOUNT      KG  ...
# 750    FOB ANY PORT IN TAIWANEVA 7470M PRIME VIRGIN ...
# 867    TERMS OF PRICE CFR189MT OF DOPAS PER PROFORMA...
# 998    20 MT DOAAT USD 230000MTTOTAL AMOUNT  USD 460...
# 1022                 CFR ANY JAPANESE PORTRNABS AF3510
# 1056   FOB ANY PORT IN TAIWANEVA 7350M PRIME GRADE 5...
# 1163   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 1212   TERMS OF PRICE CFRDOPAS PER PROFORMA INVOICE ...
# 1407   1EVA 7350MQUANTITY 150 MTUNIT PRICE USD3435MT...
# 1724   NO COMMODITY QUANTITY  UNIT PRICE AMOUNT   MT...
#
#                               受益人          預測產品 預測產品使用方式 預測產品(取長度最長) 推薦公司事業部  \
# 401               NAN YA PLASTICS       ['EVA']     rule         EVA      2P
# 628               NAN YA PLASTICS    ['TAIWAN']     rule      TAIWAN      25
# 750              FORMOSA PLASTICS    ['TAIWAN']     rule      TAIWAN      18
# 867               NAN YA PLASTICS    ['TAIWAN']     rule      TAIWAN      27
# 998               NAN YA PLASTICS    ['TAIWAN']     rule      TAIWAN      28
# 1022  FORMOSA CHEMICALS AND FIBRE  ['JAPANESE']     rule    JAPANESE      4A
# 1056             FORMOSA PLASTICS    ['TAIWAN']     rule      TAIWAN      18
# 1163             FORMOSA PLASTICS    ['TAIWAN']     rule      TAIWAN      18
# 1212              NAN YA PLASTICS    ['TAIWAN']     rule      TAIWAN      27
# 1407             FORMOSA PLASTICS    ['TAIWAN']     rule      TAIWAN      18
# 1724             FORMOSA PLASTICS       ['EVA']     rule         EVA      17
#
#      根據產品預測代號 利用公司名稱預測公司代號 集成預測代號               from
# 401    ['12']            2     2G  1018(1015-16).xls
# 628    ['1P']            2     29           1026.xls
# 750    ['1P']            1     1P           1028.xls
# 867    ['1P']            2     26           1102.xls
# 998    ['1P']            2     2P           1108.xls
# 1022   ['21']            4     4P           1109.xls
# 1056   ['1P']            1     1P           1109.xls
# 1163   ['1P']            1     1P           1117.xls
# 1212   ['1P']            2     29           1118.xls
# 1407   ['1P']            1     1P           1126.xls
# 1724   ['12']            1     12           1207.xls

# %%
import numpy as np
寶典by_ricky = pd.DataFrame()
寶典by_ricky['CODIV'] = df['推薦公司事業部']
寶典by_ricky['DIVNM'] = np.nan
寶典by_ricky['ITEMNM'] = df['預測產品(取長度最長)']
寶典by_ricky['memo'] = 'ricky + der'
print(寶典by_ricky.shape)
寶典by_ricky
# Out:
# (11, 4)
#      CODIV  DIVNM    ITEMNM         memo
# 401     2P    NaN       EVA  ricky + der
# 628     25    NaN    TAIWAN  ricky + der
# 750     18    NaN    TAIWAN  ricky + der
# 867     27    NaN    TAIWAN  ricky + der
# 998     28    NaN    TAIWAN  ricky + der
# 1022    4A    NaN  JAPANESE  ricky + der
# 1056    18    NaN    TAIWAN  ricky + der
# 1163    18    NaN    TAIWAN  ricky + der
# 1212    27    NaN    TAIWAN  ricky + der
# 1407    18    NaN    TAIWAN  ricky + der
# 1724    17    NaN       EVA  ricky + der

# %%
#寶典by_ricky.to_excel('../data/寶典/寶典人工處理後/寶典_by_ricky.xlsx',index=False)#
#寶典by_ricky.to_excel('../output/寶典_by_ricky.xlsx',index=False)

# %%
#ok
