# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
df = pd.read_excel('../predict_result/0927_1022_test.xlsx')
print(df.columns)
df.head()
# Out:
# Index(['45A', '項次', '電文代號', '銀行', '20', '回傳代碼', '回傳訊息', '建檔日期', '受益人', '金額',
#        '推薦公司事業部', '是否已轉MIS', 'MEMO', 'from', '50', '59', '46A', '47A', '78',
#        'memo', 'Unnamed: 5', '預測產品', '預測產品(取長度最長)', '預測產品使用方式', '根據產品預測部門',
#        '根據產品預測代號', '預測開狀人', '利用公司名稱預測公司代號', '集成預測代號', '銀行輸入', '開狀銀行', '正確與否',
#        '錯誤原因', '信用狀代碼(LCNO)'],
#       dtype='object')
#                                                  45A  項次   電文代號  銀行  \
# 0   48 MT PVC SUSPENSION RESIN GRADE S65AT THE RA...   8  mt700  16
# 1   TETRAHYDROFURAN AT USD 5550 TOTAL AMOUNTUSD 1...  10  mt700  16
# 2   A 19800 MT OF TAIRILAC AG15A1HABS ABS RESINAT...  11  mt700  16
# 3   80 MT PVC SUSPENSION RESIN GRADE S65S AT THE ...  12  mt700  16
# 4   PVC SUSPENSION RESIN S70RQUANTITY 72 MT UNIT ...  13  mt700  16
#
#                  20  回傳代碼                       回傳訊息                 建檔日期  \
# 0   0006MLC00034022   200  {"MESSAGE":"","CODE":200}  2021/09/24 12:31:17
# ...

# %%
df = df.loc[df['錯誤原因']!='無錯誤',['受益人','預測產品','預測產品(取長度最長)','推薦公司事業部','根據產品預測代號','利用公司名稱預測公司代號','集成預測代號']]
print(df.shape)
df
# Out:
# (98, 7)
#                                            受益人  \
# 1                  NAN YA PLASTICS CORPORATION
# 7                 FORMOSA PLASTICS CORPORATION
# 13                  NANYA PLASTICS CORPORATION
# 24                 NAN YA PLASTICS CORPORATION
# 30                 NAN YA PLASTICS CORPORATION
# 61                 NAN YA PLASTICS CORPORATION
# 74                 NAN YA PLASTICS CORPORATION
# 78                 NAN YA PLASTICS CORPORATION
# 83                  FORMOSA PETROCHEMICAL CORP
# 88                  FORMOSA PETROCHEMICAL CORP
# 94                 NAN YA PLASTICS CORPORATION
# 102               FORMOSA PLASTICS CORPORATION
# 103                NAN YA PLASTICS CORPORATION
# 150               FORMOSA PLASTICS CORPORATION
# 151                NAN YA PLASTICS CORPORATION
# 153               FORMOSA PLASTICS CORPORATION
# 154                NAN YA PLASTICS CORPORATION
# 162                NAN YA PLASTICS CORPORATION
# 165                NAN YA PLASTICS CORPORATION
# ...
