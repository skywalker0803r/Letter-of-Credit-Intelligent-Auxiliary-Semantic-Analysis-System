# %%
import pandas as pd

df1 = pd.read_csv('..\data\對應表\信用狀代碼對應表.csv',index_col=0).iloc[:,-5:]
df1
# Out:
#                                                      產品名  \
# 0                                   PVC SUSPENSION RESIN
# 1                                    PVC COPOLYMER RESIN
# 2                                          PVC RESIN S60
# 3                                    MASS PVC RESIN B 57
# 4                                     PHTHALIC ANHYDRIDE
# ...                                                  ...
# 20728  VISCOSE STAPLE FIBER 15DX40MM SEMI DULLNON WOV...
# 20729  VISCOSE STAPLE FIBER 15DX40MM SEMI DULLFOR NON...
# 20730  VISCOSE STAPLE FIBER 30DX38MM SEMI DULLFOR NON...
# 20731                   PVC RESIN SUSPENSION GRADE S 65D
# 20733                                     PVC RESIN S 60
#
#                                                      開狀人  \
# 0                              RYTOIL PETROCHEMICALS LLP
# 1                                 S R POLYVINYL LTD42613
# 2                          OSWAL CABLE PRODUCTS PVT LTDA
# ...

# %%
df2 = pd.read_excel('../predict_result/1004測試結果.xlsx')[['預測產品(取長度最長)','預測開狀人','受益人','開狀銀行','信用狀代碼(LCNO)']]
df2.head()
# Out:
#               預測產品(取長度最長)                                              預測開狀人  \
# 0   PVC SUPER CLEAR SHEET    PVC SUPER CLEAR SHEET ORDER 24 SEP 202117 65...
# 1        ETHYLENE IN BULK                SHANGHAI JINSHAN TRADINGCORPORATION
# 2  POLYESTER STAPLE FIBER                           POLYESTER STAPLE FIBER4D
# 3              TAISOX EVA                          XIAMEN PORT TRADING COLTD
# 4                PP RESIN                          U KWONG INDUSTRIAL CO LTD
#
#                             受益人                         開狀銀行      信用狀代碼(LCNO)
# 0   NAN YA PLASTICS CORPORATION                          SEP   LC011100035293
# 1    FORMOSA PETROCHEMICAL CORP       BANK OF COMMUNICATIONS  LC0110221A00507
# 2   NAN YA PLASTICS CORPORATION  HABIB METROPOLITAN BANK LTD  LC/01/056/20506
# 3  FORMOSA PLASTICS CORPORATION                       TAISOX  LC0959121000011
# 4  FORMOSA PLASTICS CORPORATION                  BNP PARIBAS  00001LCH2100211

# %%
for i in df2.head()['信用狀代碼(LCNO)'].values:
    display(df1[df1.LCNO==i].sample(1))
# Out:
#             產品名                   開狀人                          受益人  \
# 2111  PVC SHEET  AKROS TRADING CO LTD  NAN YA PLASTICS CORPORATION
#
#                                開狀銀行            LCNO
# 2111  THE MIZUHO BANKLTDHEAD OFFICE  LC011100035293
#                             產品名                                開狀人  \
# 746  BASE OIL 500N DENSITY08725  H AND R CHINA DAXIE COLTDDETAILED
#
#                             受益人            開狀銀行             LCNO
# 746  FORMOSA PETROCHEMICAL CORP  BANK OF NINGBO  LC0110221A00507
#                           產品名                開狀人                          受益人  \
# 14704  POLYESTER STAPLE FIBER  MUNDIA EXPORTS1ST  NAN YA PLASTICS CORPORATION
#
#                                                     開狀銀行             LCNO
# 14704  HABIB METROPOLITAN BANK LTD CPU- IMPORT 9TH FL...  LC/01/056/20506
#             產品名                                開狀人  \
# 159  EVA TAISOX  FUJIAN JINJIANG IMP AND EXP COLTD
#
# ...
