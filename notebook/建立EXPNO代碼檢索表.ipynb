# %%
import pandas as pd
import numpy as np
import random
import torch
from pytorch_lightning import seed_everything
from transformers import DistilBertTokenizerFast
from transformers import DistilBertForQuestionAnswering
from transformers import pipeline
from tqdm import tqdm_notebook as tqdm
import re

def set_seed(seed = int):
    '''Sets the seed of the entire notebook so results are the same every time we run.
    This is for REPRODUCIBILITY.'''
    np.random.seed(seed)
    random_state = np.random.RandomState(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    seed_everything(seed)
    return random_state
random_state = set_seed(42)
df = pd.read_excel('..\data\combined_excel.xlsx',index_col=0)
print(df.columns)
df['產品名'] = np.nan#df['SPEC']
df['開狀銀行'] = df['LTADDRESS.1'].apply(lambda x:str(x)[:-3])#LTADDRESS的末三碼可以剃除
df['受益人'] = np.nan
df['開狀人'] = np.nan
df = df[['45A', #產品名輸入
'50', # 開狀人輸入
'59', # 公司名(受益人)輸入
'46A','47A','78', #開狀銀行輸入
'產品名',
'開狀人',
'受益人',
'開狀銀行',
'EXPNO']]
df.head()
# Out:
# Global seed set to 42
# Index(['59', '45A', '46A', '47A', '31D', '44C', '48', '71D', '78', '50', '51A',
#        '51D', 'LCNO', 'LTADDRESS.1', 'from', 'EXPNO', 'LCBK', 'CU1', 'SPEC'],
#       dtype='object')
#                                                  45A  \
# 0  SHIPMENT OFPVC SUSPENSION RESIN S-65D QTY 18 M...
# 1  17 MT  PVC COPOLYMER RESIN, C-15  AT USD 1470 ...
# 2  +TERMS OF SALE: CIF NHAVA SHEVA PORT, INDIA++7...
# 3  MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4  PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
#
#                                                   50  \
# 0  RYTOIL PETROCHEMICALS LLPBASEMENT 2095, I BLOC...
# 1  S R POLYVINYL LTD4261/3, JAI MATA MARKET TRI N...
# 2  OSWAL CABLE PRODUCTS PVT LTDA 93/1 WAZIRPUR GR...
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4  AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
#
#                                                   59  \
# 0  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 1  FORMOSA PLASTICS CORPORATION201, TUNG HWA NORT...
# 2  FORMOSA PLASTICS CORPORATION201. TUNG HWA N. R...
# 3  FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4  NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
#
#                                                  46A  \
# 0  1. FULL SET OF(3 NEGOTIABLE COPIES PLUS 3 NON-...
# 1  1.DRAFTS FOR 100PCT OF INVOICE VALUE..2.COMPLE...
# 2  +1. SHIPPED ON BOARD OCEAN BILLS OF LADING (FU...
# 3  1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4  1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
#
#                                                  47A  \
# 0  1.ORIGINAL DOCUMENTS TO BE SENT IN ONE LOT BY ...
# 1  1.ALL DOCUMENT MUST MENTION OUR LC NUMBER AND ...
# 2  +1. DOCUMENTS TO BE SENT DIRECTLY TO US IN ONE...
# 3  1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4  (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
#
#                                                   78  產品名  開狀人  受益人  \
# 0  WE SHALL REMIT THE PROCEEDS TO YOU UPON RECEIP...  NaN  NaN  NaN
# 1                                   REFER FIELD 47A.  NaN  NaN  NaN
# 2  WE HEREBY UNDERTAKE WITH DRAWERS AND/OR BONAFI...  NaN  NaN  NaN
# 3  +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...  NaN  NaN  NaN
# 4  IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...  NaN  NaN  NaN
#
#         開狀銀行     EXPNO
# 0  PUNBINBBA       NaN
# 1  INDBINBBA       NaN
# 2  CITIINBXA       NaN
# 3  ICICINBBA  11G11F59
# 4  NCBKSAJEA  27P11346

# %%
class 產品名預測器(object):
    def __init__(self,data_path,model_path):
        
        # 讀取訓練資料(SPEC)
        train_df = pd.read_csv(data_path)[['string_X_train','Y_label','EXPNO']]
        train_df['Y_label'] = train_df['Y_label'].apply(lambda x:self.product_name_postprocess(x))

        # 讀取台塑網提供之(寶典人工手動修正過刪除線問題)
        root = '../data/寶典/寶典人工處理後/'
        df5 = pd.read_excel(root+'寶典.v6.20211020.xlsx',engine='openpyxl')[['CODIV','DIVNM','ITEMNM']]
        df5 = df5.rename(columns={'ITEMNM':'品名','DIVNM':'公司事業部門','CODIV':'公司代號'})
        df_by_ricky = pd.read_excel(root+'寶典_by_ricky.xlsx',engine='openpyxl')[['CODIV','DIVNM','ITEMNM']]
        df_by_ricky = df_by_ricky.rename(columns={'ITEMNM':'品名','DIVNM':'公司事業部門','CODIV':'公司代號'})
        df = df5.append(df_by_ricky) # 合併官方寶典和我做的寶典
        df['品名'] = df['品名'].apply(lambda x:self.product_name_postprocess(x)) #品名後處理
        
        # 寶典跟bert
        self.產品集合 = set(df['品名'].values.tolist() + train_df['Y_label'].values.tolist())
        self.nlp = self.load_nlp(model_path)
    
    def product_name_postprocess(self,x):
        x = str(x)
        x = x.replace('-',' ')
        x = x.strip()
        x = self.add_space(x)
        x = str(x).upper() # 轉大寫字串
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 去除中文
        x = re.sub(r'[^\w\s]','',x) # 去除標點符號
        x = x.replace('\n', '').replace('\r', '').replace('\t', '') # 換行符號去除
        return x
    
    def add_space(self,x):
        if (' ' not in x)&(len(x)<=5):
            return ' ' + x + ' '
        else:
            return x
    
    def load_nlp(self,path):
        tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
        model = DistilBertForQuestionAnswering.from_pretrained("distilbert-base-uncased")
        model.load_state_dict(torch.load(path,map_location=torch.device('cpu')))
        model.eval()
        nlp = pipeline('question-answering', model=model.to('cpu'), tokenizer=tokenizer)
        return nlp
    
    def preprocess_45(self,x):
        x = str(x).upper() # 轉大寫字串
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 去除中文
        x = re.sub(r'[^\w\s]','',x) # 去除標點符號
        x = x.replace('\n', '').replace('\r', '').replace('\t', '') # 換行符號去除
        str.strip(x) # 移除左右空白
        # 去除多重空白
        x = x.replace('   ', ' ')
        x = x.replace('  ', ' ')
        # 出現在頭的 就不可能對到前後加空格的 這種情形要想想怎麼對照(加上左右空白)
        x = ' ' + x + ' '
        return x

    def bert_postprocess(self,x):
        x = x.replace('QUANTITY','')
        if 'PACKING' in x: #像這個 有辦法將 packing之後的都幹掉嗎
            x = x[:x.find('PACKING')+len('PACKING')]
        return x

    # 寶典比對法
    def Collection_method(self,df,產品集合,x_col):
        labels = {}
        labels_max = {}
        for i in tqdm(df.index):
            products = []
            for p in 產品集合:
                if p in df.loc[i,x_col]:
                    products.append(p) # 加入候選清單
            if len(products) > 0: # 如果有找到產品 
                labels[i] = products # 複數個產品,之後配合公司去篩選出一個
                labels_max[i] = max(products,key=len) # 取長度最長的產品
            else:
                labels[i] = 'not find'
                labels_max[i] = 'not find'
        predict = pd.DataFrame(index=labels.keys(),columns=['預測產品'])
        predict['預測產品'] = labels.values()
        predict['預測產品(取長度最長)'] = labels_max.values()
        predict['預測產品使用方式'] = 'rule'
        return predict
    
    # bert 預測法
    def model_predict(self,nlp,df,question='What is the product name?',start_from0=False,x_col='45A',y_col='預測產品'):
        table = pd.DataFrame()
        idx_list = sorted(df.index.tolist())
        for i in tqdm(idx_list):
            sample = df.loc[[i]]
            string_X_train = sample[x_col].values[0]
            QA_input = {
                'question': question,
                'context': string_X_train
            }
            res = nlp(QA_input)
            if start_from0 == False:
                predict = QA_input['context'][res['start']:res['end']]
            else:
                predict = QA_input['context'][0:res['end']]
            row = pd.DataFrame({y_col:predict},index=[i])
            table = table.append(row)
        table[y_col] = table[y_col].apply(lambda x:[self.bert_postprocess(x)])
        return [ i[0] for i in table[y_col].values.tolist()] # list of string
    
    def predict(self,df):
        df['45A'] = df['45A'].apply(lambda x:self.preprocess_45(x)) 
        output = self.Collection_method(df,self.產品集合,'45A')
        not_find_idx = output.loc[output['預測產品'] == 'not find',:].index
        if len(not_find_idx) > 0:
            bert_predict = self.model_predict(self.nlp,df.loc[not_find_idx])
            output.loc[not_find_idx,'預測產品'] = [ [i] for i in bert_predict]
            output.loc[not_find_idx,'預測產品(取長度最長)'] = bert_predict
            output.loc[not_find_idx,'預測產品使用方式'] = 'bert'
        output.loc[not_find_idx,'預測產品(取長度最長)'] = output.loc[not_find_idx,'預測產品(取長度最長)'].apply(lambda x:self.product_name_postprocess(x))
        return output



    
product_predictor = 產品名預測器('../data/preprocess_for_SQUAD_產品.csv','../models/Product_Data_SQuAD_model_product.pt')
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
error_idx = list(set(df.index) - set(df.dropna(subset=['產品名']).index))
df.loc[error_idx,'產品名'] = product_predictor.predict(df.loc[error_idx,['45A']])['預測產品(取長度最長)'].values.tolist()
df
# Out:
# C:\Users\ricky\anaconda3\envs\bert_env\lib\site-packages\ipykernel_launcher.py:69: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/20737 [00:00<?, ?it/s]
# C:\Users\ricky\anaconda3\envs\bert_env\lib\site-packages\ipykernel_launcher.py:90: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1653 [00:00<?, ?it/s]
# C:\Users\ricky\AppData\Roaming\Python\Python37\site-packages\transformers\tokenization_utils_base.py:705: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# C:\Users\ricky\AppData\Roaming\Python\Python37\site-packages\transformers\pipelines\question_answering.py:302: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   for span_id in range(num_spans)
#                                                      45A  \
# 0      SHIPMENT OFPVC SUSPENSION RESIN S-65D QTY 18 M...
# 1      17 MT  PVC COPOLYMER RESIN, C-15  AT USD 1470 ...
# 2      +TERMS OF SALE: CIF NHAVA SHEVA PORT, INDIA++7...
# 3      MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4      PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# ...                                                  ...
# 20732  PVC SUSPENSION RESIN S65D FOR 70MT AT USD 1270...
# 20733  70.00 MT (IN 4X20 FT CONTAINERS)_x000D_\nPVC R...
# 20734  EPOXY RESIN_x000D_\nNPEF-178_x000D_\nFOB ANY P...
# 20735  EPOXY RESIN_x000D_\nNPEL-128_x000D_\nCIF SAVAN...
# 20736  EPOXY RESIN_x000D_\nNPEL-127_x000D_\nPO NO. 45...
#
#                                                       50  \
# 0      RYTOIL PETROCHEMICALS LLPBASEMENT 2095, I BLOC...
# 1      S R POLYVINYL LTD4261/3, JAI MATA MARKET TRI N...
# 2      OSWAL CABLE PRODUCTS PVT LTDA 93/1 WAZIRPUR GR...
# 3      OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4      AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# ...                                                  ...
# 20732  MOHAN TRADING CO._x000D_\n19 - DADA COLONY, IN...
# 20733  YASH PACKAGING_x000D_\nPLOT NO. A2/2220, 3RD P...
# 20734  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
# 20735  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
# 20736  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
#
#                                                       59  \
# 0      FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 1      FORMOSA PLASTICS CORPORATION201, TUNG HWA NORT...
# 2      FORMOSA PLASTICS CORPORATION201. TUNG HWA N. R...
# 3      FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4      NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# ...                                                  ...
# 20732  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20733  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20734  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
# 20735  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
# 20736  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
#
#                                                      46A  \
# 0      1. FULL SET OF(3 NEGOTIABLE COPIES PLUS 3 NON-...
# 1      1.DRAFTS FOR 100PCT OF INVOICE VALUE..2.COMPLE...
# 2      +1. SHIPPED ON BOARD OCEAN BILLS OF LADING (FU...
# 3      1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4      1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# ...                                                  ...
# 20732  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICES IN ...
# 20733  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
# 20734  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
# 20735  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
# 20736  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
#
#                                                      47A  \
# 0      1.ORIGINAL DOCUMENTS TO BE SENT IN ONE LOT BY ...
# 1      1.ALL DOCUMENT MUST MENTION OUR LC NUMBER AND ...
# 2      +1. DOCUMENTS TO BE SENT DIRECTLY TO US IN ONE...
# 3      1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4      (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# ...                                                  ...
# 20732  1.ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+_...
# 20733  1. ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+...
# 20734  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
# 20735  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
# 20736  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
#
#                                                       78  \
# 0      WE SHALL REMIT THE PROCEEDS TO YOU UPON RECEIP...
# 1                                       REFER FIELD 47A.
# 2      WE HEREBY UNDERTAKE WITH DRAWERS AND/OR BONAFI...
# 3      +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4      IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# ...                                                  ...
# 20732  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20733  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20734  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
# 20735  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
# 20736  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
#
#                          產品名  開狀人  受益人       開狀銀行     EXPNO
# 0       PVC SUSPENSION RESIN  NaN  NaN  PUNBINBBA       NaN
# 1        PVC COPOLYMER RESIN  NaN  NaN  INDBINBBA       NaN
# 2              PVC RESIN S60  NaN  NaN  CITIINBXA       NaN
# 3              PVC RESIN B57  NaN  NaN  ICICINBBA  11G11F59
# 4      PHTHALIC ANHYDRIDE PA  NaN  NaN  NCBKSAJEA  27P11346
# ...                      ...  ...  ...        ...       ...
# 20732   PVC SUSPENSION RESIN  NaN  NaN  KKBKINBBA       NaN
# 20733          PVC RESIN S60  NaN  NaN  KKBKINBBA  11G11J49
# 20734            EPOXY RESIN  NaN  NaN  CTCBHKHHA       NaN
# 20735            EPOXY RESIN  NaN  NaN  CTCBHKHHA       NaN
# 20736            EPOXY RESIN  NaN  NaN  CTCBHKHHA       NaN
#
# [20737 rows x 11 columns]

# %%
class 開狀人預測器(object):
    def __init__(self):
        self.開狀人寶典 = pd.read_csv('../data/寶典/開狀人寶典.csv')
        self.開狀人尾綴 = pd.read_csv('../data/寶典/開狀人尾綴.csv')
        self.nlp = self.load_nlp('../models/Product_Data_SQuAD_model_開狀人.pt')
        
    def load_nlp(self,path):
        tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
        model = DistilBertForQuestionAnswering.from_pretrained("distilbert-base-uncased")
        model.load_state_dict(torch.load(path,map_location=torch.device('cpu')))
        model.eval()
        nlp = pipeline('question-answering', model=model.to('cpu'), tokenizer=tokenizer)
        return nlp
    
    def preprocess_50(self,x):
        x = str(x)
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 去除中文
        x = re.sub(r'[^\w\s]','',x) # 去除標點符號
        x = x.replace('\n', '').replace('\r', '').replace('\t', '') # 換行符號去除
        return str.strip(x) # 移除左右空白

    def model_predict(self,nlp,df,question,x_col,y_col,start_from0=False):
        table = pd.DataFrame()
        idx_list = sorted(df.index.tolist())
        for i in tqdm(idx_list):
            sample = df.loc[[i]]
            string_X_train = sample[x_col].values[0]
            QA_input = {
                'question': question,
                'context': string_X_train
            }
            res = nlp(QA_input)
            if start_from0 == False:
                predict = QA_input['context'][res['start']:res['end']]
            else:
                predict = QA_input['context'][0:res['end']]
            row = pd.DataFrame({y_col:predict},index=[i])
            table = table.append(row)
        return [ i for i in table[y_col].values.tolist()] # list of string

    def predict(self,df):
        df['50'] = df['50'].apply(lambda x:self.preprocess_50(x))
        df['預測開狀人'] = 'not find'
        for i in df.index:
            x = df.loc[i,'50']
            # 1寶典匹配法
            for a in self.開狀人寶典['開狀人'].values.tolist():
                if (a in x) & (df.loc[i,'預測開狀人']=='not find'):
                    df.loc[i,'預測開狀人'] = a
            # 2尾綴匹配法
            for b in self.開狀人尾綴['尾綴'].values.tolist():
                if (b in x) & (df.loc[i,'預測開狀人']=='not find'):
                    df.loc[i,'預測開狀人'] = x[:x.find(b)+len(b)]
            # 若 1,2 方法都不行則用bert
            not_find_idx = df.loc[df['預測開狀人'] == 'not find',:].index
            if len(not_find_idx) > 0:
                bert_predict = self.model_predict(
                    self.nlp,
                    df.rename(columns={'50':'string_X_train'}).loc[not_find_idx],
                    question='What is the Applicant name?',
                    start_from0=True,
                    x_col='string_X_train',
                    y_col='預測開狀人')
                df.loc[not_find_idx,'預測開狀人'] = bert_predict
        return df
開狀人_predictor = 開狀人預測器()
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
error_idx = list(set(df.index) - set(df.dropna(subset=['開狀人']).index))
df.loc[error_idx,'開狀人'] = 開狀人_predictor.predict(df.loc[error_idx,['50']])['預測開狀人'].values.tolist()
df
# Out:
# C:\Users\ricky\anaconda3\envs\bert_env\lib\site-packages\ipykernel_launcher.py:25: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/20736 [00:00<?, ?it/s]
#                                                      45A  \
# 0      SHIPMENT OFPVC SUSPENSION RESIN S-65D QTY 18 M...
# 1      17 MT  PVC COPOLYMER RESIN, C-15  AT USD 1470 ...
# 2      +TERMS OF SALE: CIF NHAVA SHEVA PORT, INDIA++7...
# 3      MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4      PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# ...                                                  ...
# 20732  PVC SUSPENSION RESIN S65D FOR 70MT AT USD 1270...
# 20733  70.00 MT (IN 4X20 FT CONTAINERS)_x000D_\nPVC R...
# 20734  EPOXY RESIN_x000D_\nNPEF-178_x000D_\nFOB ANY P...
# 20735  EPOXY RESIN_x000D_\nNPEL-128_x000D_\nCIF SAVAN...
# 20736  EPOXY RESIN_x000D_\nNPEL-127_x000D_\nPO NO. 45...
#
#                                                       50  \
# 0      RYTOIL PETROCHEMICALS LLPBASEMENT 2095, I BLOC...
# 1      S R POLYVINYL LTD4261/3, JAI MATA MARKET TRI N...
# 2      OSWAL CABLE PRODUCTS PVT LTDA 93/1 WAZIRPUR GR...
# 3      OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4      AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# ...                                                  ...
# 20732  MOHAN TRADING CO._x000D_\n19 - DADA COLONY, IN...
# 20733  YASH PACKAGING_x000D_\nPLOT NO. A2/2220, 3RD P...
# 20734  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
# 20735  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
# 20736  ALLCHEM INTERNATIONAL PTY., LTD._x000D_\n4/F, ...
#
#                                                       59  \
# 0      FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 1      FORMOSA PLASTICS CORPORATION201, TUNG HWA NORT...
# 2      FORMOSA PLASTICS CORPORATION201. TUNG HWA N. R...
# 3      FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4      NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# ...                                                  ...
# 20732  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20733  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20734  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
# 20735  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
# 20736  NAN YA PLASTICS CORP_x000D_\n201 TUNG HWA N. R...
#
#                                                      46A  \
# 0      1. FULL SET OF(3 NEGOTIABLE COPIES PLUS 3 NON-...
# 1      1.DRAFTS FOR 100PCT OF INVOICE VALUE..2.COMPLE...
# 2      +1. SHIPPED ON BOARD OCEAN BILLS OF LADING (FU...
# 3      1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4      1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# ...                                                  ...
# 20732  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICES IN ...
# 20733  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
# 20734  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
# 20735  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
# 20736  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
#
#                                                      47A  \
# 0      1.ORIGINAL DOCUMENTS TO BE SENT IN ONE LOT BY ...
# 1      1.ALL DOCUMENT MUST MENTION OUR LC NUMBER AND ...
# 2      +1. DOCUMENTS TO BE SENT DIRECTLY TO US IN ONE...
# 3      1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4      (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# ...                                                  ...
# 20732  1.ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+_...
# 20733  1. ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+...
# 20734  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
# 20735  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
# 20736  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
#
#                                                       78  \
# 0      WE SHALL REMIT THE PROCEEDS TO YOU UPON RECEIP...
# 1                                       REFER FIELD 47A.
# 2      WE HEREBY UNDERTAKE WITH DRAWERS AND/OR BONAFI...
# 3      +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4      IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# ...                                                  ...
# 20732  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20733  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20734  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
# 20735  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
# 20736  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...
#
#                          產品名                                         開狀人  受益人  \
# 0       PVC SUSPENSION RESIN                   RYTOIL PETROCHEMICALS LLP  NaN
# 1        PVC COPOLYMER RESIN                      S R POLYVINYL LTD42613  NaN
# 2              PVC RESIN S60               OSWAL CABLE PRODUCTS PVT LTDA  NaN
# 3              PVC RESIN B57                    OJUS PETROCHEMICALS LLPC  NaN
# 4      PHTHALIC ANHYDRIDE PA  AHMED SAEED AFIFI FACTORY CO FORRESINS LTD  NaN
# ...                      ...                                         ...  ...
# 20732   PVC SUSPENSION RESIN                            MOHAN TRADING CO  NaN
# 20733          PVC RESIN S60                        YASH PACKAGING_x000D  NaN
# 20734            EPOXY RESIN               ALLCHEM INTERNATIONAL PTY LTD  NaN
# 20735            EPOXY RESIN               ALLCHEM INTERNATIONAL PTY LTD  NaN
# 20736            EPOXY RESIN               ALLCHEM INTERNATIONAL PTY LTD  NaN
#
#             開狀銀行     EXPNO
# 0      PUNBINBBA       NaN
# 1      INDBINBBA       NaN
# 2      CITIINBXA       NaN
# 3      ICICINBBA  11G11F59
# 4      NCBKSAJEA  27P11346
# ...          ...       ...
# 20732  KKBKINBBA       NaN
# 20733  KKBKINBBA  11G11J49
# 20734  CTCBHKHHA       NaN
# 20735  CTCBHKHHA       NaN
# 20736  CTCBHKHHA       NaN
#
# [20737 rows x 11 columns]

# %%
class 公司預測器(object):
    def __init__(self):
        self.公司寶典 = pd.read_csv('../data/寶典/公司寶典加尾綴(擴充版).csv')
        self.nlp = self.load_nlp('../models/Product_Data_SQuAD_model_公司.pt')
        
    def load_nlp(self,path):
        tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
        model = DistilBertForQuestionAnswering.from_pretrained("distilbert-base-uncased")
        model.load_state_dict(torch.load(path,map_location=torch.device('cpu')))
        model.eval()
        nlp = pipeline('question-answering', model=model.to('cpu'), tokenizer=tokenizer)
        return nlp
    
    def preprocess_59(self,x): # 公司59欄位預處理
        x = str(x) #轉str
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 去除中文
        x = re.sub(r'[^\w\s]','',x) # 去除標點符號
        x = x.replace('\n', '').replace('\r', '').replace('\t', '') # 去除換行符號
        x = x.replace('r','').replace('n','')
        return str.strip(x)

    def model_predict(self,nlp,df,question,x_col,y_col,start_from0=False):
        table = pd.DataFrame()
        idx_list = sorted(df.index.tolist())
        for i in tqdm(idx_list):
            sample = df.loc[[i]]
            string_X_train = sample[x_col].values[0]
            QA_input = {
                'question': question,
                'context': string_X_train
            }
            res = nlp(QA_input)
            if start_from0 == False:
                predict = QA_input['context'][res['start']:res['end']]
            else:
                predict = QA_input['context'][0:res['end']]
            row = pd.DataFrame({y_col:predict},index=[i])
            table = table.append(row)
        return [ i for i in table[y_col].values.tolist()] # list of string


    def predict(self,df):
        df['59'] = df['59'].apply(lambda x:self.preprocess_59(x))
        df['受益人'] = 'not find'
        for i in df.index:
            x = df.loc[i,'59']
            # 1寶典匹配法
            for a in self.公司寶典['公司英文名稱'].values.tolist():
                if (a in x) & (df.loc[i,'受益人'] == 'not find'):
                    df.loc[i,'受益人'] = a
            # 2尾綴匹配法
            for b in self.公司寶典['尾綴'].values.tolist():
                if (b in x) & (df.loc[i,'受益人'] == 'not find'):
                    df.loc[i,'受益人'] = x[:x.find(b)+len(b)]
        # 若 1,2 方法都不行則用bert
        not_find_idx = df.loc[df['受益人'] == 'not find',:].index
        if len(not_find_idx) > 0:
            bert_predict = self.model_predict(
                self.nlp,
                df.rename(columns={'59':'string_X_train'}).loc[not_find_idx],
                question = 'What is the company name?',
                start_from0 = True,
                x_col='string_X_train',
                y_col='受益人')
            df.loc[not_find_idx,'受益人'] = bert_predict
        return df
受益人_predictor = 公司預測器()
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
error_idx = list(set(df.index) - set(df.dropna(subset=['受益人']).index))
df.loc[error_idx,'受益人'] = 受益人_predictor.predict(df.loc[error_idx,['59']])['受益人'].values.tolist()
df.sample(15)
# Out:
# C:\Users\ricky\anaconda3\envs\bert_env\lib\site-packages\ipykernel_launcher.py:25: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/6471 [00:00<?, ?it/s]
#                                                      45A  \
# 4680   CIF NAGOYA_x000D_\n1)PURCHASE CONTRACT NO.JG18...
# 447    NO.  COMMODITY    QUANTITY     UNIT PRICE    A...
# 14773  1.POLYESTER RECYCLED TEXTURED YARN A GRADE2.PO...
# 9015                                                 NaN
# 2751   25.2 MT TAIRILAC ABS RESINS GRADE NO AG12A0 AT...
# 911    SHIPMENT OF_x000D_\nPVC SUSPENSION RESIN S-65D...
# 11114                                                NaN
# 10690                                                NaN
# 6903   COMMODITY          QUANTITY   UNIT PRICE_x000D...
# 11167                                                NaN
# 10489                                                NaN
# 9888                                                 NaN
# 19530  ._x000D_\n -----------------------------------...
# 18671  PP RESIN GRADE NO.K1P38SX, QTY:201,600KG, UNIT...
# 2277   +HS CODE: 7410.21-1000_x000D_\n COPPER CLAD LA...
#
#                                                       50  \
# 4680   MARUBENI INTEX CO.,LTD._x000D_\n2-1 DOJIMAHAMA...
# 447    BINH TIEN BIEN HOA COMPANY LIMITED_x000D_\nADD...
# 14773  LIANG WOEI FIBRE CO., LTD.ROOM C,FL.10,NO.63,S...
# 9015                                                 NaN
# 2751   MONSTER POLYMERS INC._x000D_\nPO BOX 145, 300 ...
# 911    RYTOIL PETROCHEMICALS LLP_x000D_\nBASEMENT 209...
# 11114                                                NaN
# 10690                                                NaN
# 6903   SHANTOU LIXIN PLASTIC PRODUCTS_x000D_\nCO.,LTD...
# 11167                                                NaN
# 10489                                                NaN
# 9888                                                 NaN
# 19530  KCE TECHNOLOGY COMPANY LIMITED._x000D_\n117,11...
# 18671  POLYONE DISTRIBUTION TRADING_x000D_\nJINQIAO,2...
# 2277   DAP CORP_x000D_\n404-1, BOCHE-RI, MIYANG-MYEON...
#
#                                                       59  \
# 4680   NAN YA PLASTICS CORP_x000D_\n201,TUNG HWA NORT...
# 447    FORMOSA PLASTICS CORPORATION_x000D_\nADD.:201 ...
# 14773  NAN YA PLASTICS CORP.POLYESTER FIBER DIV.201 T...
# 9015                                              200115
# 2751   FORMOSA CHEMICALS AND FIBRE CORP_x000D_\n201, ...
# 911    FORMOSA PLASTICS CORPORATION_x000D_\n201,TUNG ...
# 11114                                             200902
# 10690                                             200319
# 6903   FORMOSA PLASTICS CORPORATION_x000D_\nNO.201, T...
# 11167                                             200907
# 10489                                             200324
# 9888                                              200226
# 19530  NAN YA PLASTICS CORPORATION_x000D_\n201 TUN HU...
# 18671  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 2277   NAN YA PLASTICS CORP_x000D_\n3F, 201, TUNG HWA...
#
#                                                      46A  \
# 4680   + COMMERCIAL INVOICE IN 1 ORIGINAL 2 COPIES_x0...
# 447    1. SIGNED COMMERCIAL INVOICE_x000D_\n2. FULL (...
# 14773  +SIGNED COMMERCIAL INVOICE IN 2 ORIGINAL(S) IN...
# 9015                                  ANY PORT IN TAIWAN
# 2751   +3 ORIGINALS AND 3 COPIES COMMERCIAL INVOICE  ...
# 911    1. FULL SET OF(3 NEGOTIABLE COPIES PLUS 3 NON-...
# 11114                                 ANY TAIWAN SEAPORT
# 10690                                     KAOHSIUNG PORT
# 6903   1. SIGNED COMMERCIAL INVOICE IN 6 ORIGINALS IN...
# 11167                                 ANY TAIWANESE PORT
# 10489                                 ANY PORT IN TAIWAN
# 9888                                  ANY PORT IN TAIWAN
# 19530  ._x000D_\n1)COMMERCIAL INVOICE IN ONE ORIGINAL...
# 18671  1.MANUALLY SIGNED COMMERCIAL INVOICE IN 2 ORIG...
# 2277   +SIGNED COMMERCIAL INVOICE IN 3 COPIES_x000D_\...
#
#                                                      47A  \
# 4680   + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ 5 P...
# 447    1. ONE ADDITIONAL COPY/PHOTOCOPY OF ALL REQUIR...
# 14773  +AN EXTRA COPY OF ALL DOCUMENTS IS REQUIRED FO...
# 9015                CAT LAI PORT, HOCHIMINH CITY,VIETNAM
# 2751   +CONTAINER SHIPMENT REQUIRED._x000D_\nPO C8012...
# 911    1.ORIGINAL DOCUMENTS TO BE SENT IN ONE LOT BY ...
# 11114                          KARACHI SEAPORT, PAKISTAN
# 10690                            NHAVA SHEVA PORT, INDIA
# 6903   1. ALL DOCUMENTS TO BE FORWARDED IN ONE COVER....
# 11167                             BUSAN PORT SOUTH KOREA
# 10489                                JEBEL ALI PORT, UAE
# 9888                CAT LAI PORT, HOCHIMINH CITY,VIETNAM
# 19530  ._x000D_\n1)A DISCREPANCY FEE OF USD 50.00 WIL...
# 18671  1.ALL DOCUMENTS TO BE FORWARDED IN ONE COVER._...
# 2277   +ALL DOCUMENTS PRESENTED MUST BE IN ENGLISH._x...
#
#                                                       78  \
# 4680   ALL DOCS TO BE SENT DIRECTLY TO US(3-10-19, MI...
# 447    +THE AMOUNT AND DATE OF EACH DRAWING MUST BE E...
# 14773  +A DISCREPANCY FEE OF USD70.00(JPY7700.00 OR E...
# 9015                                                  10
# 2751   UNLESS OTHERWISE SPECIFIED NEGOTIATING BANK WI...
# 911    WE SHALL REMIT THE PROCEEDS TO YOU UPON RECEIP...
# 11114             15/FRM SHIPMENT DATE BUT WITHIN EXPIRY
# 10690                  21/DAYS FROM THE DATE OF SHIPMENT
# 6903   UPON OUR RECEIPT OF THE DOCUMENTS IN ORDER, WE...
# 11167                                                 21
# 10489                                                NaN
# 9888                                                  10
# 19530  DOCUMENTS TO BE DESPATCHED IN ONE SET BY COURI...
# 18671  UPON OUR RECEIPT OF THE DOCUMENTS IN ORDER, WE...
# 2277   THE AMOUNT OF EACH DRAFT MUST BE ENDORSED ON T...
#
#                            產品名                                         開狀人  \
# 4680   POLYESTER FILAMENT YARN                        MARUBENI INTEX COLTD
# 447                    PACKING          BINH TIEN BIEN HOA COMPANY LIMITED
# 14773                POLYESTER                 LIANG WOEI FIBRE CO LTDROOM
# 9015                      NAN                                          nan
# 2751                 ABS RESIN                        MONSTER POLYMERS INC
# 911       PVC SUSPENSION RESIN                   RYTOIL PETROCHEMICALS LLP
# 11114                     NAN                                          nan
# 10690                     NAN                                          nan
# 6903          HDPE TAISOX 8010  SHANTOU LIXIN PLASTIC PRODUCTS_x000D_COLTD
# 11167                     NAN                                          nan
# 10489                     NAN                                          nan
# 9888                      NAN                                          nan
# 19530                 LAMINATE              KCE TECHNOLOGY COMPANY LIMITED
# 18671                 PP RESIN                POLYONE DISTRIBUTION TRADING
# 2277      COPPER CLAD LAMINATE                                    DAP CORP
#
#                                                  受益人       開狀銀行     EXPNO
# 4680                            NAN YA PLASTICS CORP  SMBCJPJTD       NaN
# 447                     FORMOSA PLASTICS CORPORATION  ICBVVNVXA  18F12021
# 14773                           NAN YA PLASTICS CORP       BANK       NaN
# 9015                                          200115  BKTWTWT0A  14C9C060
# 2751                FORMOSA CHEMICALS AND FIBRE CORP  ROYCCAT2D  4AT11056
# 911                     FORMOSA PLASTICS CORPORATION  PUNBINBBA       NaN
# 11114                                         200902  BKTWTWT0A  2PL16168
# 10690                                         200319  BKTWTWT0A  61B15247
# 6903                    FORMOSA PLASTICS CORPORATION  BKCHCNBJA  18F15029
# 11167                                         200907  BKTWTWT0A  2PL15156
# 10489                                         200324  BKTWTWT0A  4A716A02
# 9888                                          200226  BKTWTWT0A  2PL16168
# 19530                    NAN YA PLASTICS CORPORATION  BKKBTHBKB       NaN
# 18671  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  BKCHCNBJA       NaN
# 2277                            NAN YA PLASTICS CORP  KODBKRSEA  2MQ13C07

# %%
#==================銀行預測部分==================================================================

class 銀行預測器(object):
    def __init__(self):
        self.銀行列表 = np.load('../data/寶典/銀行寶典.npy')
        self.nlp = self.load_nlp('../models/Product_Data_SQuAD_model_銀行.pt')
        
    def load_nlp(self,path):
        tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
        model = DistilBertForQuestionAnswering.from_pretrained("distilbert-base-uncased")
        model.load_state_dict(torch.load(path,map_location=torch.device('cpu')))
        model.eval()
        nlp = pipeline('question-answering', model=model.to('cpu'), tokenizer=tokenizer)
        return nlp
    
    def preprocess_銀行(self,x):
        x = str(x) # 0.轉字串
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 1.去除中文
        x = re.sub('[’!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~，。,.]', '', x) # 2.去除標點符號
        x = x.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ') # 3.去除換行符號
        x = x.replace('x000D','') # 4.移除'x000D'
        x = ' ' + str.strip(x) + ' ' # 5.移除左右空白 在左右各加一格空白
        return x
    
    def preprocess_銀行輸出(self,x):
        x = str(x) # 0.轉字串
        x = re.sub('[\u4e00-\u9fa5]', '', x) # 1.去除中文
        x = re.sub('[’!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~，。,.]', '', x) # 2.去除標點符號
        x = x.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ') # 3.去除換行符號
        x = ' '.join([ i.replace(' ','') for i in x.split(' ')])
        x = str.strip(x) # 4.移除左右空白
        return x

    def model_predict(self,nlp,df,question,x_col,y_col,start_from0=False):
        table = pd.DataFrame()
        idx_list = sorted(df.index.tolist())
        for i in tqdm(idx_list):
            sample = df.loc[[i]]
            string_X_train = sample[x_col].values[0]
            QA_input = {
                'question': question,
                'context': str(string_X_train)
            }
            res = nlp(QA_input)
            if start_from0 == False:
                predict = QA_input['context'][res['start']:res['end']]
            else:
                predict = QA_input['context'][0:res['end']]
            row = pd.DataFrame({y_col:predict},index=[i])
            table = table.append(row)
        return [ i for i in table[y_col].values.tolist()] # list of string

    def predict(self,df):
        df['銀行輸入'] = df['46A'] + ' ' + df['47A'] + ' ' + df['78']
        df['開狀銀行'] = 'not find'
        for i in df.index:
            x = df.loc[i,'銀行輸入']
            # 先試寶典匹配法
            for a in self.銀行列表:
                if (str(a) in str(x)) & (df.loc[i,'開狀銀行'] == 'not find'):
                    df.loc[i,'開狀銀行'] = a
        # 若寶典匹配不到則用bert
        not_find_idx = df.loc[df['開狀銀行'] == 'not find',:].index
        if len(not_find_idx) > 0:
            bert_predict = self.model_predict(
                self.nlp,
                df.rename(columns={'銀行輸入':'string_X_train'}).loc[not_find_idx],
                question = 'What is the bank name?',
                start_from0 = False,
                x_col = 'string_X_train',
                y_col = '開狀銀行',
                )
            df.loc[not_find_idx,'開狀銀行'] = bert_predict
            df.loc[not_find_idx,'開狀銀行'] = df.loc[not_find_idx,'開狀銀行'].apply(lambda x:self.preprocess_銀行輸出(x))
        return df
銀行_predictor = 銀行預測器()
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#error_idx = list(set(df.index) - set(df.dropna(subset=['開狀銀行']).index))
#df.loc[error_idx,'開狀銀行'] = 銀行_predictor.predict(df.loc[error_idx,['46A','47A','78']])['開狀銀行'].values.tolist()
df.head(10)
# Out:
#                                                  45A  \
# 0  SHIPMENT OFPVC SUSPENSION RESIN S-65D QTY 18 M...
# 1  17 MT  PVC COPOLYMER RESIN, C-15  AT USD 1470 ...
# 2  +TERMS OF SALE: CIF NHAVA SHEVA PORT, INDIA++7...
# 3  MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4  PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# 5  + COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0...
# 6  +TERM OF SALE: CIF MUNDRA SEAPORT, INDIA++70 M...
# 7  COMMODITY                                     ...
# 8  COMMODITY                                     ...
# 9  COMMODITY                                     ...
#
#                                                   50  \
# 0  RYTOIL PETROCHEMICALS LLPBASEMENT 2095, I BLOC...
# 1  S R POLYVINYL LTD4261/3, JAI MATA MARKET TRI N...
# 2  OSWAL CABLE PRODUCTS PVT LTDA 93/1 WAZIRPUR GR...
# 3  OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4  AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# 5  MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...
# 6  OSWAL CABLE PRODUCTS PVT LTDA 93/1 WAZIRPUR GR...
# 7  CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# 8  CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# 9  CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
#
#                                                   59  \
# 0  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 1  FORMOSA PLASTICS CORPORATION201, TUNG HWA NORT...
# 2  FORMOSA PLASTICS CORPORATION201. TUNG HWA N. R...
# 3  FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4  NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5  FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 6  FORMOSA PLASTICS CORPORATION201, TUNG HWA NORT...
# 7  NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 8  NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 9  NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
#
#                                                  46A  \
# 0  1. FULL SET OF(3 NEGOTIABLE COPIES PLUS 3 NON-...
# 1  1.DRAFTS FOR 100PCT OF INVOICE VALUE..2.COMPLE...
# 2  +1. SHIPPED ON BOARD OCEAN BILLS OF LADING (FU...
# 3  1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4  1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5  1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 6  +1. SHIPPED ON BOARD OCEAN BILLS OF LADING (FU...
# 7  +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 8  +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 9  +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
#
#                                                  47A  \
# 0  1.ORIGINAL DOCUMENTS TO BE SENT IN ONE LOT BY ...
# 1  1.ALL DOCUMENT MUST MENTION OUR LC NUMBER AND ...
# 2  +1. DOCUMENTS TO BE SENT DIRECTLY TO US IN ONE...
# 3  1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4  (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 5  +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 6  +1. DOCUMENTS TO BE SENT DIRECTLY TO US IN ONE...
# 7  ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 8  ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 9  ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
#
#                                                   78  \
# 0  WE SHALL REMIT THE PROCEEDS TO YOU UPON RECEIP...
# 1                                   REFER FIELD 47A.
# 2  WE HEREBY UNDERTAKE WITH DRAWERS AND/OR BONAFI...
# 3  +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4  IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5  + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 6  WE HEREBY UNDERTAKE WITH DRAWERS AND/OR BONAFI...
# 7  ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 8  ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 9  ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
#
#                                 產品名  \
# 0              PVC SUSPENSION RESIN
# 1               PVC COPOLYMER RESIN
# 2                     PVC RESIN S60
# 3                     PVC RESIN B57
# 4             PHTHALIC ANHYDRIDE PA
# 5                 CIF HAIPHONG PORT
# 6              PVC SUSPENSION RESIN
# 7  POLYESTER PARTIALY ORIENTED YARN
# 8  POLYESTER PARTIALY ORIENTED YARN
# 9  POLYESTER PARTIALY ORIENTED YARN
#
#                                           開狀人                           受益人  \
# 0                   RYTOIL PETROCHEMICALS LLP  FORMOSA PLASTICS CORPORATION
# 1                      S R POLYVINYL LTD42613  FORMOSA PLASTICS CORPORATION
# 2               OSWAL CABLE PRODUCTS PVT LTDA  FORMOSA PLASTICS CORPORATION
# 3                    OJUS PETROCHEMICALS LLPC  FORMOSA PLASTICS CORPORATION
# 4  AHMED SAEED AFIFI FACTORY CO FORRESINS LTD   NAN YA PLASTICS CORPORATION
# 5            MINH KHANG CHEMICAL TRADINGJOINT  FORMOSA PLASTICS CORPORATION
# 6               OSWAL CABLE PRODUCTS PVT LTDA  FORMOSA PLASTICS CORPORATION
# 7                             CHORI CO LTDTEL   NAN YA PLASTICS CORPORATION
# 8                             CHORI CO LTDTEL   NAN YA PLASTICS CORPORATION
# 9                             CHORI CO LTDTEL   NAN YA PLASTICS CORPORATION
#
#         開狀銀行     EXPNO
# 0  PUNBINBBA       NaN
# 1  INDBINBBA       NaN
# 2  CITIINBXA       NaN
# 3  ICICINBBA  11G11F59
# 4  NCBKSAJEA  27P11346
# 5  VBAAVNVXA  18Q0C097
# 6  CITIINBXA       NaN
# 7  MHCBJPJTD  25D11126
# 8  MHCBJPJTD  25D11126
# 9  MHCBJPJTD  25D12134

# %%
df.shape
# Out:
# (20737, 11)

# %%
df.dropna(subset=['產品名','開狀人','受益人','開狀銀行','EXPNO']).shape
# Out:
# (13973, 11)

# %%
df = df.dropna(subset=['產品名','開狀人','受益人','開狀銀行','EXPNO'])
df
# Out:
#                                                      45A  \
# 3      MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4      PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# 5      + COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0...
# 7      COMMODITY                                     ...
# 8      COMMODITY                                     ...
# ...                                                  ...
# 20728  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20729  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20730  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20731  187 MT PVC RESIN SUSPENSION GRADE S-65D OF FOR...
# 20733  70.00 MT (IN 4X20 FT CONTAINERS)_x000D_\nPVC R...
#
#                                                       50  \
# 3      OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4      AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# 5      MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...
# 7      CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# 8      CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# ...                                                  ...
# 20728  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20729  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20730  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20731  PREMIER POLYFILM LTD_x000D_\nA-13, INDUSTRIAL ...
# 20733  YASH PACKAGING_x000D_\nPLOT NO. A2/2220, 3RD P...
#
#                                                       59  \
# 3      FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4      NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5      FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 7      NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 8      NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# ...                                                  ...
# 20728  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20729  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20730  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20731  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20733  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
#
#                                                      46A  \
# 3      1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4      1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5      1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 7      +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 8      +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# ...                                                  ...
# 20728  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20729  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20730  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20731  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICE IN T...
# 20733  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
#
#                                                      47A  \
# 3      1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4      (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 5      +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 7      ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 8      ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# ...                                                  ...
# 20728  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20729  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20730  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20731  1.ALL DOCUMENTS MUST BE IN ENGLISH LANGUAGE._x...
# 20733  1. ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+...
#
#                                                       78  \
# 3      +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4      IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5      + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 7      ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 8      ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# ...                                                  ...
# 20728  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20729  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20730  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20731  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20733  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
#
#                                     產品名  \
# 3                         PVC RESIN B57
# 4                 PHTHALIC ANHYDRIDE PA
# 5                     CIF HAIPHONG PORT
# 7      POLYESTER PARTIALY ORIENTED YARN
# 8      POLYESTER PARTIALY ORIENTED YARN
# ...                                 ...
# 20728        VISCOSE RAYON STAPLE FIBER
# 20729        VISCOSE RAYON STAPLE FIBER
# 20730        VISCOSE RAYON STAPLE FIBER
# 20731                         PVC RESIN
# 20733                     PVC RESIN S60
#
#                                               開狀人  \
# 3                        OJUS PETROCHEMICALS LLPC
# 4      AHMED SAEED AFIFI FACTORY CO FORRESINS LTD
# 5                MINH KHANG CHEMICAL TRADINGJOINT
# 7                                 CHORI CO LTDTEL
# 8                                 CHORI CO LTDTEL
# ...                                           ...
# 20728                        MARUBENI INTEX COLTD
# 20729                        MARUBENI INTEX COLTD
# 20730                        MARUBENI INTEX COLTD
# 20731                        PREMIER POLYFILM LTD
# 20733                        YASH PACKAGING_x000D
#
#                                                  受益人       開狀銀行     EXPNO
# 3                       FORMOSA PLASTICS CORPORATION  ICICINBBA  11G11F59
# 4                        NAN YA PLASTICS CORPORATION  NCBKSAJEA  27P11346
# 5                       FORMOSA PLASTICS CORPORATION  VBAAVNVXA  18Q0C097
# 7                        NAN YA PLASTICS CORPORATION  MHCBJPJTD  25D11126
# 8                        NAN YA PLASTICS CORPORATION  MHCBJPJTD  25D11126
# ...                                              ...        ...       ...
# 20728  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G0C164
# 20729  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G12129
# 20730  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G12129
# 20731                   FORMOSA PLASTICS CORPORATION  KKBKINBBA  11G11G85
# 20733                   FORMOSA PLASTICS CORPORATION  KKBKINBBA  11G11J49
#
# [13973 rows x 11 columns]

# %%
df = df.replace('nan',np.nan)
df.dropna(subset=['產品名','開狀人','受益人','開狀銀行','EXPNO']).shape
# Out:
# (8231, 11)

# %%
df = df.dropna(subset=['產品名','開狀人','受益人','開狀銀行','EXPNO'])
df
# Out:
#                                                      45A  \
# 3      MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4      PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# 5      + COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0...
# 7      COMMODITY                                     ...
# 8      COMMODITY                                     ...
# ...                                                  ...
# 20728  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20729  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20730  CFR KOBE, JAPAN_x000D_\nVISCOSE RAYON STAPLE F...
# 20731  187 MT PVC RESIN SUSPENSION GRADE S-65D OF FOR...
# 20733  70.00 MT (IN 4X20 FT CONTAINERS)_x000D_\nPVC R...
#
#                                                       50  \
# 3      OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 4      AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# 5      MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...
# 7      CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# 8      CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# ...                                                  ...
# 20728  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20729  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20730  MARUBENI INTEX CO.,LTD._x000D_\n1-2-1 DOJIMAHA...
# 20731  PREMIER POLYFILM LTD_x000D_\nA-13, INDUSTRIAL ...
# 20733  YASH PACKAGING_x000D_\nPLOT NO. A2/2220, 3RD P...
#
#                                                       59  \
# 3      FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 4      NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 5      FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 7      NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 8      NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# ...                                                  ...
# 20728  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20729  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20730  FORMOSA CHEMICALS AND FIBRE_x000D_\nCORPORATIO...
# 20731  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
# 20733  FORMOSA PLASTICS CORPORATION_x000D_\n201, TUNG...
#
#                                                      46A  \
# 3      1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 4      1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 5      1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 7      +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 8      +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# ...                                                  ...
# 20728  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20729  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20730  + COMMERCIAL INVOICE IN 3 ORIGINAL_x000D_\n+ 2...
# 20731  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICE IN T...
# 20733  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
#
#                                                      47A  \
# 3      1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 4      (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 5      +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 7      ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 8      ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# ...                                                  ...
# 20728  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20729  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20730  + T.T.REIMBURSEMENT : PROHIBITED_x000D_\n+ INS...
# 20731  1.ALL DOCUMENTS MUST BE IN ENGLISH LANGUAGE._x...
# 20733  1. ALL DOCUMENTS MUST BE IN ENGLISH._x000D_\n+...
#
#                                                       78  \
# 3      +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 4      IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 5      + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 7      ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 8      ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# ...                                                  ...
# 20728  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20729  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20730  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 20731  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 20733  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
#
#                                     產品名  \
# 3                         PVC RESIN B57
# 4                 PHTHALIC ANHYDRIDE PA
# 5                     CIF HAIPHONG PORT
# 7      POLYESTER PARTIALY ORIENTED YARN
# 8      POLYESTER PARTIALY ORIENTED YARN
# ...                                 ...
# 20728        VISCOSE RAYON STAPLE FIBER
# 20729        VISCOSE RAYON STAPLE FIBER
# 20730        VISCOSE RAYON STAPLE FIBER
# 20731                         PVC RESIN
# 20733                     PVC RESIN S60
#
#                                               開狀人  \
# 3                        OJUS PETROCHEMICALS LLPC
# 4      AHMED SAEED AFIFI FACTORY CO FORRESINS LTD
# 5                MINH KHANG CHEMICAL TRADINGJOINT
# 7                                 CHORI CO LTDTEL
# 8                                 CHORI CO LTDTEL
# ...                                           ...
# 20728                        MARUBENI INTEX COLTD
# 20729                        MARUBENI INTEX COLTD
# 20730                        MARUBENI INTEX COLTD
# 20731                        PREMIER POLYFILM LTD
# 20733                        YASH PACKAGING_x000D
#
#                                                  受益人       開狀銀行     EXPNO
# 3                       FORMOSA PLASTICS CORPORATION  ICICINBBA  11G11F59
# 4                        NAN YA PLASTICS CORPORATION  NCBKSAJEA  27P11346
# 5                       FORMOSA PLASTICS CORPORATION  VBAAVNVXA  18Q0C097
# 7                        NAN YA PLASTICS CORPORATION  MHCBJPJTD  25D11126
# 8                        NAN YA PLASTICS CORPORATION  MHCBJPJTD  25D11126
# ...                                              ...        ...       ...
# 20728  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G0C164
# 20729  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G12129
# 20730  FORMOSA CHEMICALS AND FIBRE_x000D_CORPORATION  SMBCJPJTD  41G12129
# 20731                   FORMOSA PLASTICS CORPORATION  KKBKINBBA  11G11G85
# 20733                   FORMOSA PLASTICS CORPORATION  KKBKINBBA  11G11J49
#
# [8231 rows x 11 columns]

# %%
df.to_csv('../data/對應表/EXPNO對應表.csv')

# %%
1+1
# Out:
# 2
