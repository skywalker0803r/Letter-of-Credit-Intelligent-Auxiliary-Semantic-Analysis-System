# %%
import requests
url = 'https://gist.githubusercontent.com/skywalker0803r/823ecfa11147c918ce805409bf4d733f/raw/24d559f020ade561f5b4ba49e02d1634e7dfb067/Letter-of-Credit-Intelligent-Auxiliary-Semantic-Analysis-System.py'
exec(requests.get(url).text)
a = coresystem(['apple','banana'])
a.predict('applee')
# Out:
# C:\Users\ricky\anaconda3\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/對應表/信用狀代碼對應表.csv')

# %%
df
# Out:
#        Unnamed: 0                                                45A  \
# 0               0  SHIPMENT OFPVC SUSPENSION RESIN S-65D QTY 18 M...
# 1               1  17 MT  PVC COPOLYMER RESIN, C-15  AT USD 1470 ...
# 2               2  +TERMS OF SALE: CIF NHAVA SHEVA PORT, INDIA++7...
# 3               3  MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 4               4  PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# ...           ...                                                ...
# 13964       20732  PVC SUSPENSION RESIN S65D FOR 70MT AT USD 1270...
# 13965       20733  70.00 MT (IN 4X20 FT CONTAINERS)\r\nPVC RESIN ...
# 13966       20734  EPOXY RESIN\r\nNPEF-178\r\nFOB ANY PORT OF TAIWAN
# 13967       20735        EPOXY RESIN\r\nNPEL-128\r\nCIF SAVANNAH, GA
# 13968       20736  EPOXY RESIN\r\nNPEL-127\r\nPO NO. 4500537656\r...
#
#                                                       50  \
# 0      RYTOIL PETROCHEMICALS LLPBASEMENT 2095, I BLOC...
# ...

# %%
train_df = df.iloc[:-1]
test_df = df.iloc[-1:]
test_df
# Out:
#        Unnamed: 0                                                45A  \
# 13968       20736  EPOXY RESIN\r\nNPEL-127\r\nPO NO. 4500537656\r...
#
#                                                       50  \
# 13968  ALLCHEM INTERNATIONAL PTY., LTD.\r\n4/F, BLOCK...
#
#                                                       59  \
# 13968  NAN YA PLASTICS CORP\r\n201 TUNG HWA N. ROAD\r...
#
#                                                      46A  \
# 13968  +SIGNED COMMERCIAL INVOICE IN 1 ORIGINAL AND 1...
#
#                                                      47A  \
# 13968  +DOCUMENTS MUST BE PRESENTED WITHIN 10 DAYS AF...
#
#                                                       78          產品名  \
# 13968  +TO NEGOTIATING BANK ONLY: PLEASE FORWARD ALL ...  EPOXY RESIN
#
#                                    開狀人                   受益人  \
# 13968  ALLCHEM INTERNATIONAL PTY LTD4F  NAN YA PLASTICS CORP
#
#                    開狀銀行              LCNO
# ...

# %%
col = ['45A','50','46A']
s = {}
for i in col:
    s[i] = coresystem(data = train_df[i].values.tolist()[:100])

# %%
s[col[0]].predict(test_df[col[0]].values[0])
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 17.00it/s]
# ...

# %%
test_df[col[0]].values[0]
# Out:
# 'EPOXY RESIN\r\nNPEL-127\r\nPO NO. 4500537656\r\nITEM CODE: 032784R01B01\r\nFOB ANY PORT OF TAIWAN'

# %%
train_df[train_df[col[0]]=='EPOXY RESIN.1. RESIN NPEL 128 - QTY 76,800 KGS AT USD 3.07 PER KG.CIF - JEBEL ALI , UNITED ARAB EMIRATES']
# Out:
#     Unnamed: 0                                                45A  \
# 62          63  EPOXY RESIN.1. RESIN NPEL 128 - QTY 76,800 KGS...
#
#                                                    50  \
# 62  HARIS AL AFAQ LTDP O BOX 61394, DUBAI,JEBEL AL...
#
#                                                    59  \
# 62  NANYA PLASTICS CORPORATION201 TUNG HWA NORTH R...
#
#                                                   46A  \
# 62  1. COMMERCIAL INVOICE(S) IN ORIGINAL PLUS 4 CO...
#
#                                                   47A  \
# 62  1. SHIPPING MARKS: HAA/CAPA/7525(INVOICE, BILL...
#
#                                                    78          產品名  \
# 62  UPON RECEIPT OF COMPLYING DOCUMENTS WE SHALL R...  EPOXY RESIN
#
#                    開狀人                         受益人              開狀銀行  \
# 62  HARIS AL AFAQ LTDP  NANYA PLASTICS CORPORATION  UNITED ARAB BANK
#
#                 LCNO
# 62  ILC1021/21/71845

# %%
test_df[col[0]].values[0]
# Out:
# 'EPOXY RESIN\r\nNPEL-127\r\nPO NO. 4500537656\r\nITEM CODE: 032784R01B01\r\nFOB ANY PORT OF TAIWAN'
