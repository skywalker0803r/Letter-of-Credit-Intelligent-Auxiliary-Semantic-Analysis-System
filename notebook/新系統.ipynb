# %%
import requests
url = 'https://gist.githubusercontent.com/skywalker0803r/823ecfa11147c918ce805409bf4d733f/raw/24d559f020ade561f5b4ba49e02d1634e7dfb067/Letter-of-Credit-Intelligent-Auxiliary-Semantic-Analysis-System.py'
exec(requests.get(url).text)
a = coresystem(['apple','banana'])
a.predict('applee')
# Out:
# C:\Users\ricky\anaconda3\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForQuestionAnswering: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 2/2 [00:00<00:00, 2005.40it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# {'apple': 1.0, 'banana': 6.0}
# {'apple': 1.0, 'banana': 6.0}
# 'apple'

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/對應表/EXPNO對應表.csv')

# %%
df
# Out:
#       Unnamed: 0                                                45A  \
# 0              3  MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 US...
# 1              4  PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT ...
# 2              5  + COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0...
# 3              7  COMMODITY                                     ...
# 4              8  COMMODITY                                     ...
# ...          ...                                                ...
# 8226       20728  CFR KOBE, JAPAN\r\nVISCOSE RAYON STAPLE FIBER\...
# 8227       20729  CFR KOBE, JAPAN\r\nVISCOSE RAYON STAPLE FIBER\...
# 8228       20730  CFR KOBE, JAPAN\r\nVISCOSE RAYON STAPLE FIBER\...
# 8229       20731  187 MT PVC RESIN SUSPENSION GRADE S-65D OF FOR...
# 8230       20733  70.00 MT (IN 4X20 FT CONTAINERS)\r\nPVC RESIN ...
#
#                                                      50  \
# 0     OJUS PETROCHEMICALS LLPC 289 NIRALA NAGAR LUCK...
# 1     AHMED SAEED AFIFI FACTORY CO. FORRESINS LTD. P...
# 2     MINH KHANG CHEMICAL TRADINGJOINT STOCK COMPANY...
# 3     CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# 4     CHORI CO., LTD.TEL NO.81-76-232-3008FAX NO.81-...
# ...                                                 ...
# 8226  MARUBENI INTEX CO.,LTD.\r\n1-2-1 DOJIMAHAMA, K...
# 8227  MARUBENI INTEX CO.,LTD.\r\n1-2-1 DOJIMAHAMA, K...
# 8228  MARUBENI INTEX CO.,LTD.\r\n1-2-1 DOJIMAHAMA, K...
# 8229  PREMIER POLYFILM LTD\r\nA-13, INDUSTRIAL AREA,...
# 8230  YASH PACKAGING\r\nPLOT NO. A2/2220, 3RD PHASE,...
#
#                                                      59  \
# 0     FORMOSA PLASTICS CORPORATION201,TUNG HWA N ROA...
# 1     NAN YA PLASTICS CORPORATION201 TUN HWA NORTH R...
# 2     FORMOSA PLASTICS CORPORATION201,TUNG HWA NORTH...
# 3     NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# 4     NAN YA PLASTICS CORPORATIONNO.201,TUNG HWA N.R...
# ...                                                 ...
# 8226  FORMOSA CHEMICALS AND FIBRE\r\nCORPORATION\r\n...
# 8227  FORMOSA CHEMICALS AND FIBRE\r\nCORPORATION\r\n...
# 8228  FORMOSA CHEMICALS AND FIBRE\r\nCORPORATION\r\n...
# 8229  FORMOSA PLASTICS CORPORATION\r\n201, TUNG HWA ...
# 8230  FORMOSA PLASTICS CORPORATION\r\n201, TUNG HWA ...
#
#                                                     46A  \
# 0     1. SIGNED COMMERCIAL INVOICE IN 3 ORIGINALS AN...
# 1     1. SIGNED COMMERCIAL INVOICE IN ORIGINAL AND 4...
# 2     1.SIGNED COMMERCIAL INVOICE IN 03 ORIGINALS AN...
# 3     +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# 4     +SIGNED COMMERCIAL INVOICE IN TRIPLICATE INDIC...
# ...                                                 ...
# 8226  + COMMERCIAL INVOICE IN 3 ORIGINAL\r\n+ 2/3 SE...
# 8227  + COMMERCIAL INVOICE IN 3 ORIGINAL\r\n+ 2/3 SE...
# 8228  + COMMERCIAL INVOICE IN 3 ORIGINAL\r\n+ 2/3 SE...
# 8229  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICE IN T...
# 8230  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
#
#                                                     47A  \
# 0     1. ALL DOCUMENTS MUST BE IN ENGLISH.2. ALL DOC...
# 1     (A) ALL DOCUMENTS AND DRAFTS (IF CALLED FOR UN...
# 2     +ALL DOCUMENTS MUST MADE IN ENGLISH.+ALL DOCUM...
# 3     ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# 4     ALL DRAFT(S) DRAWN HEREUNDER MUST BE MARKED ''...
# ...                                                 ...
# 8226  + T.T.REIMBURSEMENT : PROHIBITED\r\n+ INSURANC...
# 8227  + T.T.REIMBURSEMENT : PROHIBITED\r\n+ INSURANC...
# 8228  + T.T.REIMBURSEMENT : PROHIBITED\r\n+ INSURANC...
# 8229  1.ALL DOCUMENTS MUST BE IN ENGLISH LANGUAGE.\r...
# 8230  1. ALL DOCUMENTS MUST BE IN ENGLISH.\r\n+\r\n2...
#
#                                                      78  \
# 0     +UPON RECEIPT OF CREDIT COMPLIANT DOCUMENTS AT...
# 1     IN REIMBURSEMENT OF NEGOTIATION MADE BY YOUIN ...
# 2     + UPON RECEIPT OF ALL DOCUMENTS SENT TO US(VIE...
# 3     ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# 4     ALL DOCUMENTS INCLUDING BENEFICIARY'S DRAFT(S)...
# ...                                                 ...
# 8226  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 8227  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 8228  ALL DOCS TO BE SENT DIRECTLY TO US (3-10-19, M...
# 8229  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
# 8230  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...
#
#                                                     產品名  \
# 0                                   MASS PVC RESIN B-57
# 1                           (鄰苯二甲酐)\nPHTHALIC ANHYDRIDE
# 2     LINEAR LOW DENSITY\nPOLYETHYLENE RESIN\nTAISOX...
# 3                     POLYESTER PARTIALY\nORIENTED YARN
# 4                     POLYESTER PARTIALY\nORIENTED YARN
# ...                                                 ...
# 8226  VISCOSE STAPLE FIBER \n1.5DX40MM SEMI DULL\n(N...
# 8227  VISCOSE STAPLE FIBER \n1.5DX40MM SEMI DULL\n(F...
# 8228  VISCOSE STAPLE FIBER \n3.0DX38MM SEMI DULL\n(F...
# 8229                 PVC RESIN SUSPENSION \nGRADE S-65D
# 8230                                     PVC RESIN S-60
#
#                                                     開狀人  \
# 0                              OJUS PETROCHEMICALS LLPC
# 1            AHMED SAEED AFIFI FACTORY CO FORRESINS LTD
# 2                      MINH KHANG CHEMICAL TRADINGJOINT
# 3                                       CHORI CO LTDTEL
# 4                                       CHORI CO LTDTEL
# ...                                                 ...
# 8226                            MARUBENI INTEX COLTD121
# 8227                            MARUBENI INTEX COLTD121
# 8228                            MARUBENI INTEX COLTD121
# 8229                            PREMIER POLYFILM LTDA13
# 8230  YASH PACKAGINGPLOT NO A22220 3RD PHASEGIDC VAP...
#
#                                          受益人  \
# 0               FORMOSA PLASTICS CORPORATION
# 1                NAN YA PLASTICS CORPORATION
# 2               FORMOSA PLASTICS CORPORATION
# 3                NAN YA PLASTICS CORPORATION
# 4                NAN YA PLASTICS CORPORATION
# ...                                      ...
# 8226  FORMOSA CHEMICALS AND FIBRECORPORATION
# 8227  FORMOSA CHEMICALS AND FIBRECORPORATION
# 8228  FORMOSA CHEMICALS AND FIBRECORPORATION
# 8229            FORMOSA PLASTICS CORPORATION
# 8230            FORMOSA PLASTICS CORPORATION
#
#                                                    開狀銀行     EXPNO
# 0     ICICI BANK LTD.,\nSHALIMAR TOWER, 31/54 M.G.MA...  11G11F59
# 1          NATIONAL COMMERCIAL BANK, THE\n(HEAD OFFICE)  27P11346
# 2     VIET NAM BANK FOR AGRICULTURE \nAND RURAL DEVE...  18Q0C097
# 3                      THE MIZUHO BANK,LTD.,HEAD OFFICE  25D11126
# 4                      THE MIZUHO BANK,LTD.,HEAD OFFICE  25D11126
# ...                                                 ...       ...
# 8226              SUMITOMO MITSUI BANKING \nCORP. JAPAN  41G0C164
# 8227              SUMITOMO MITSUI BANKING \nCORP. JAPAN  41G12129
# 8228              SUMITOMO MITSUI BANKING \nCORP. JAPAN  41G12129
# 8229                  KOTAK MAHINDRA BANK LIMITED INDIA  11G11G85
# 8230                 KOTAK MAHINDRA BANK LIMITED\nINDIA  11G11J49
#
# [8231 rows x 12 columns]

# %%
train_df = df.iloc[:-1]
test_df = df.iloc[-1:]
test_df
# Out:
#       Unnamed: 0                                                45A  \
# 8230       20733  70.00 MT (IN 4X20 FT CONTAINERS)\r\nPVC RESIN ...
#
#                                                      50  \
# 8230  YASH PACKAGING\r\nPLOT NO. A2/2220, 3RD PHASE,...
#
#                                                      59  \
# 8230  FORMOSA PLASTICS CORPORATION\r\n201, TUNG HWA ...
#
#                                                     46A  \
# 8230  1.BENEFICIARYS MANUALLY SIGNED COMMERCIAL INVO...
#
#                                                     47A  \
# 8230  1. ALL DOCUMENTS MUST BE IN ENGLISH.\r\n+\r\n2...
#
#                                                      78             產品名  \
# 8230  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...  PVC RESIN S-60
#
#                                                     開狀人  \
# 8230  YASH PACKAGINGPLOT NO A22220 3RD PHASEGIDC VAP...
#
#                                受益人                                開狀銀行  \
# 8230  FORMOSA PLASTICS CORPORATION  KOTAK MAHINDRA BANK LIMITED\nINDIA
#
#          EXPNO
# 8230  11G11J49

# %%
col = ['45A','50','46A']
s = {}
for i in col:
    s[i] = coresystem(data = train_df[i].values.tolist()[:100])

# %%
s[col[0]].predict(test_df[col[0]].values[0])
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  7.79it/s]
# {'MASS PVC RESIN, B-57QUANTITY 175 MT AT 1300 USD/MTAS PER PROFORMA INVOICE NO. A0B002-11DATED 10-12-2020..CIF PIPAVAV PORT, INDIA, INCOTERMS 2010': 99.0, 'PHTHALIC ANHYDRIDE (PA)QUANTITY = 306 MT UNIT PRICE = 1205 USD/MTCIF JEDDAH SEAPORT KSAAS PER INCOTERMS 2020.': 115.0, '+ COMMODITY: LLDPE TAISOX 3470+ QUANTITY: 32.0MT (2FCL/20FT)+ UNIT PRICE: USD1100.00/MT CIF HAIPHONG PORT,VIETNAM(INCOTERMS 2010).+ TOTAL AMOUNT:USD35,200.00+ COUNTRY OF ORIGIN: TAIWAN+ MAKER: FORMOSA PLASTICS CORPORATION+ PACKING: BY 25KGS NET PER BAG WITHOUT PALLET+ OTHER TERMS AND CONDITIONS AS PER CONTRACT NO.H9Q581 DATE 2020/12/14': 267.0, 'COMMODITY                                                  AMOUNT.POLYESTER TEXTURED YARN(HS CODE:5402.33)POLYESTER PARTIALY ORIENTED YARN(HS CODE:5402.46)POLYESTER FILAMENT YARN(HS CODE:5402.47)        USD  500,000.00.FOB TAIWAN': 187.0, '+ITEM1: HDPE TAISOX 8010 200MT USD1100/MTCONTRACT NO.:89K531-1CIF HAI PHONG PORT,VIETNAMITEM2: HDPE TAISOX 9001 50MT USD1090/MTCONTRACT NO.:89K531-2CIF SIHANOUKVILLE,CAMBODIAINCOTERMS 2010: CIF HAI PHONG PORT,VIETNAM AND/ORSIHANOUKVILLE,CAMBODIA': 183.0, 'COMMODITY:TAISOX 7470MQUANTITY:100MTUNIT PRICE:USD2290/MT CIF HUANGPU CHINAAMOUNT:USD229,000.00CONTRACT NO.:H9L485GOODS ORIGIN:TAIWAN': 136.0, '+COUNTRY OF ORIGIN : TAIWAN+PRICE TERMS : CIF BUSAN PORT,SOUTH KOREAGLASS FIBER YARNECG150-1/07,500KGSUSD2.12/KG': 132.0, '+COUNTRY OF ORIGIN : TAIWAN+PRICE TERMS : CIF BUSAN PORT,SOUTH KOREAGLASS FIBER YARNECG75-1/0T18,000KGSUSD1.28/KG': 132.0, "300,000 BBLS (+/-10PCT) OF GASOIL 10PPMUNIT PRICE: THE FOB MAILIAO, TAIWAN PRICE IN USD PER BBL.FOB PRICE EQUAL TO X MINUS USD0.28 PER BARREL.WHERE X EQUAL TO THE WHOLE MONTH ARITHMETIC AVERAGE OFJANUARY 2021 (MEAN OF PLATTS FOR 'GASOIL 10PPMS' UNDER THEHEADING 'SINGAPORE' PUBLISHED IN THE PLATTS ASIA PACIFIC/ARABGULF MARKETSCAN) OF PLATT'S QUOTATIONS..THE UNIT PRICE SHALL BE CALCULATED/ROUNDED TO 3 DECIMALPLACES, WITH THE THIRD DECIMAL PLACE TO BE INCREASED TO THENEXT DIGIT WHENEVER THE FOURTH DECIMAL PLACE IS FIVE OR GREATERTHAN FIVE..ANY PUBLISHED CORRECTION TO ANY OF THE RELEVANT QUOTATIONSSHALL BE TAKEN INTO ACCOUNT..TERMS OF PRICE: FOB MAILIAO, TAIWAN.COUNTRY OF ORIGIN: TAIWAN": 589.0, "Q'TY:25MTS OF EVA TAISOX 7470M AT USD2,190/MTUNDER CONTRACTNO.H9Q538-2 (PO 201117).FOB ANY TAIWANESE PORT": 124.0, '+TERMS OF SALE: CIF - NHAVA SHEVA PORT, INDIA+PVC RESIN S-65D QUANTITY 144 MTSHS CODE 390410++AS PER PROFORMA INVOICE NO.T20B15 DATED 19.11.2020': 127.0, "300,000 BBLS (+/-10PCT) OF GASOIL 10PPMUNIT PRICE: THE FOB MAILIAO, TAIWAN PRICE IN USD PER BBL.FOB PRICE EQUAL TO X MINUS USD0.28 PER BARREL.WHERE X EQUAL TO THE WHOLE MONTH ARITHMETIC AVERAGE OF JANUARY2021 (MEAN OF PLATTS FOR 'GASOIL 10PPMS' UNDER THE HEADING'SINGAPORE' PUBLISHED IN THE PLATTS ASIA PACIFIC/ARAB GULFMARKETSCAN) OF PLATT'S QUOTATIONS..THE UNIT PRICE SHALL BE CALCULATED/ROUNDED TO 3 DECIMAL PLACES,WITH THE THIRD DECIMAL PLACE TO BE INCREASED TO THE NEXT DIGITWHENEVER THE FOURTH DECIMAL PLACE IS FIVE OR GREATER THAN FIVE..ANY PUBLISHED CORRECTION TO ANY OF THE RELEVANT QUOTATIONS SHALLBE TAKEN INTO ACCOUNT..FOB MAILIAO,TAIWAN": 552.0, 'PRODUCT  : TETRAHYDROFURAN 99.8 PCT MINQUANTITY : 14,400.00 KGSAS PER PROFORMA INVOICE NO.: NBC0317 DATED 04 DEC 2020.TERMS OF SALE : CIF, NHAVA SHEVA SEA PORT, INDIA, INCOTERMS 2010': 91.0, 'CIF BUSAN+ORIGIN : TAIWAN+ GLASS FIBER YARNECG75-1/0B18,000KGS AT USD1.19/KG  USD21,420.-ECG75-1/0T18,000KGS AT USD1.28/KG  USD23,040.-': 134.0, 'POLYVINYL CHLORIDE RESIN SUSPENSION GRADE (PVC RESIN)QUANTITY 227.5 MT, GRADE - B -57, PORT- CHENNAI AS PER SC NO:A7G1756 DATED 02/01/2021,QUANTITY 157.5 MT, GRADE - S-60, PORT NHAVA SHEVA AS PER SC NO:A7G1757 DATED 02/01/2021.,QUANTITY 31.00 MT, GRADE - S-70, PORT NHAVA SHEVA AS PER SC NO:A7G17578DATED 02/01/2021.,QUANTITY 262.5 MT, GRADE - B-57, PORT MUNDRA AS PER SC NO:A7G1759 DATED 02/01/2021.,QUANTITY 160 MT, GRADE - S-65, PORT NHAVA SHEVA AS PER SC NO:A7G1760 DATED 02/01/2021.,QUANTITY 175 MT, GRADE - S-60, ...
# '17.5 MT AT 1280 USD PER TONNE EQUALS TO USD 22400 OF PVC MASSRESIN B57AS PER PI.NO. 373960 DT 11.12.2020.TERMS OF SHIPMENT: CIF, CHENNAI PORT, INDIA, INCOTERMS 2020.'

# %%
test_df[col[0]].values[0]
# Out:
# '70.00 MT (IN 4X20 FT CONTAINERS)\r\nPVC RESIN S-60\r\nAS PER SALES CONTRACT NO. T20C08 DATED 14.12.2020\r\nTERMS OF SALE: CIF, NHAVA SHEVA PORT, INDIA, INCOTERMS 2020.'

# %%
train_df[train_df[col[0]]=='17.5 MT AT 1280 USD PER TONNE EQUALS TO USD 22400 OF PVC MASSRESIN B57AS PER PI.NO. 373960 DT 11.12.2020.TERMS OF SHIPMENT: CIF, CHENNAI PORT, INDIA, INCOTERMS 2020.']
# Out:
#     Unnamed: 0                                                45A  \
# 63          81  17.5 MT AT 1280 USD PER TONNE EQUALS TO USD 22...
#
#                                                    50  \
# 63  BHARAT MONOFILAMENT ANDTEXTILES PVT. LTD.REFER...
#
#                                                    59  \
# 63  FORMOSA PLASTICS CORPORATION4F,201,TUNG HWA NO...
#
#                                                   46A  \
# 63  1.BENEFICIARY'S SIGNED COMMERCIAL INVOICES FOR...
#
#                                                   47A  \
# 63  1.ALL DOCUMENTS MUST BE IN ENGLISH.+2.ALL INVO...
#
#                                                    78             產品名  \
# 63  ON RECEIPT OF DOCUMENTS STRICTLY IN CONFORMITY...  PVC RESIN B-57
#
#                                              開狀人  \
# 63  BHARAT MONOFILAMENT ANDTEXTILES PVT LTDREFER
#
#                              受益人  \
# 63  FORMOSA PLASTICS CORPORATION
#
#                                                  開狀銀行     EXPNO
# 63  KOTAK MAHINDRA BANK LIMITED,REGD \nAND CORP.OF...  11N12G01

# %%
test_df[col[0]].values[0]
# Out:
# '70.00 MT (IN 4X20 FT CONTAINERS)\r\nPVC RESIN S-60\r\nAS PER SALES CONTRACT NO. T20C08 DATED 14.12.2020\r\nTERMS OF SALE: CIF, NHAVA SHEVA PORT, INDIA, INCOTERMS 2020.'
